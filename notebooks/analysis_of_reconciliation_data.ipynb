# %%
from itertools import islice
from collections import Counter

import json

from pandas import DataFrame
import pandas as pd

# %%
from periodo_reconciler import (
    RProperty,
    RQuery,
    PeriodoReconciler
)

p_recon = PeriodoReconciler(host='localhost:8142')

# %%
DATA_PATH = "../data/p0d.json"
rdata = json.load(open(DATA_PATH))

# %%
rdata.keys()
# Out:
# dict_keys(['periodCollections', 'id', '@context', 'type', 'primaryTopicOf'])

# %%
list(rdata['periodCollections'].values())[1]
# Out:
# {'definitions': {'p0qhb6622kc': {'editorialNote': 'Derived from FASTI, but no match in 2004 dataset.',
#    'id': 'p0qhb6622kc',
#    'label': 'geometrico',
#    'language': 'ita-latn',
#    'localizedLabels': {'eng-latn': ['Geometric', 'Phoenician'],
#     'ita-latn': ['geometrico']},
#    'note': 'http://www.worldcat.org/oclc/175286417',
#    'spatialCoverageDescription': 'Sardinia',
#    'start': {'in': {'year': '-0850'}, 'label': '2850 BP (2000)'},
#    'stop': {'in': {'year': '-0731'}, 'label': '2731 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb6622s5': {'editorialNote': 'Derived from Rijksdienst, but no match in the dataset.',
#    'id': 'p0qhb6622s5',
#    'label': 'Historie',
#    'language': 'nld-latn',
#    'localizedLabels': {'eng-latn': ['Historic'], 'nld-latn': ['Historie']},
#    'note': 'Rijksdienst voor het Cultureel Erfgoed http://data.cultureelerfgoed.nl/semnet/724277e3-6329-48f2-88d7-f84703fdd01e',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Netherlands',
#      'label': 'Netherlands'}],
#    'spatialCoverageDescription': 'Netherlands',
#    'start': {'in': {'year': '0450'}, 'label': '1550 BP (2000)'},
#    'stop': {'in': {'year': '1950'}, 'label': '50 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb6623jb': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w42chg',
#    'id': 'p0qhb6623jb',
#    'label': 'Средњи Палеолит',
#    'language': 'srp-cyrl',
#    'localizedLabels': {'eng-latn': ['Middle Paleolithic'],
#     'srp-cyrl': ['Средњи Палеолит']},
#    'spatialCoverageDescription': 'Kosovo, Serbia',
#    'start': {'in': {'year': '-100000'}, 'label': '102000 BP (2000)'},
#    'stop': {'in': {'year': '-30001'}, 'label': '32001 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb6623vz': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4m9zc',
#    'id': 'p0qhb6623vz',
#    'label': 'Perandorake e vonë',
#    'language': 'als-latn',
#    'localizedLabels': {'als-latn': ['Perandorake e vonë'],
#     'eng-latn': ['Late Imperial']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Albania',
#      'label': 'Albania'}],
#    'spatialCoverageDescription': 'Albania',
#    'start': {'in': {'year': '0300'}, 'label': '1700 BP (2000)'},
#    'stop': {'in': {'year': '0564'}, 'label': '1436 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb662487': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4rbc2',
#    'id': 'p0qhb662487',
#    'label': 'Helenistike',
#    'language': 'als-latn',
#    'localizedLabels': {'als-latn': ['Helenistike'],
#     'eng-latn': ['Hellenistic']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Albania',
#      'label': 'Albania'}],
#    'spatialCoverageDescription': 'Albania',
#    'start': {'in': {'year': '-0336'}, 'label': '2336 BP (2000)'},
#    'stop': {'in': {'year': '-0169'}, 'label': '2169 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb662549': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0pqptcdcrx',
#    'id': 'p0qhb662549',
#    'label': 'Vroege IJzertijd',
#    'language': 'nld-latn',
#    'localizedLabels': {'eng-latn': ['Early Iron age'],
#     'nld-latn': ['Vroege IJzertijd']},
#    'note': 'Rijksdienst voor het Cultureel Erfgoed http://data.cultureelerfgoed.nl/semnet/7955ec8c-463d-4fd1-bb83-eb8451c3bd28',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Netherlands',
#      'label': 'Netherlands'}],
#    'spatialCoverageDescription': 'Netherlands',
#    'start': {'in': {'year': '-0800'}, 'label': '2800 BP (2000)'},
#    'stop': {'in': {'year': '-0501'}, 'label': '2501 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb6626cm': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4sm9z',
#    'id': 'p0qhb6626cm',
#    'label': 'Hekur i zhvilluar',
#    'language': 'als-latn',
#    'localizedLabels': {'als-latn': ['Hekur i zhvilluar'],
#     'eng-latn': ['Late Iron Age']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Albania',
#      'label': 'Albania'}],
#    'spatialCoverageDescription': 'Albania',
#    'start': {'in': {'year': '-0800'}, 'label': '2800 BP (2000)'},
#    'stop': {'in': {'year': '-0601'}, 'label': '2601 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb6628nh': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0339m9pqg3',
#    'id': 'p0qhb6628nh',
#    'label': 'Μέση Παλαιολιθική',
#    'language': 'ell-latn',
#    'localizedLabels': {'ell-latn': ['Μέση Παλαιολιθική'],
#     'eng-latn': ['Middle Paleolithic']},
#    'note': 'Foundation of the Hellenic World',
#    'spatialCoverageDescription': 'Greece except Crete',
#    'start': {'in': {'year': '-98000'}, 'label': '100000 BP (2000)'},
#    'stop': {'in': {'year': '-33001'}, 'label': '35001 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb662dz7': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0zj6g8qpxx',
#    'id': 'p0qhb662dz7',
#    'label': 'Medieval',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Medieval']},
#    'note': 'ARENA1/ADS',
#    'spatialCoverageDescription': 'Norway',
#    'start': {'in': {'year': '1050'}, 'label': '950 BP (2000)'},
#    'stop': {'in': {'year': '1536'}, 'label': '464 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb662fwv': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w43fhb',
#    'id': 'p0qhb662fwv',
#    'label': 'moderna doba',
#    'language': 'slv-latn',
#    'localizedLabels': {'eng-latn': ['Modern '], 'slv-latn': ['moderna doba']},
#    'note': 'ZRC SAZU, Institute of Archaeology',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Slovenia',
#      'label': 'Slovenia'}],
#    'spatialCoverageDescription': 'Slovenia',
#    'start': {'in': {'year': '1800'}, 'label': '200 BP (2000)'},
#    'stop': {'in': {'year': '2000'}, 'label': '0 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb662md2': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4xcwm',
#    'id': 'p0qhb662md2',
#    'label': 'Касно Империал',
#    'language': 'srp-cyrl',
#    'localizedLabels': {'eng-latn': ['Late Imperial'],
#     'srp-cyrl': ['Касно Империал']},
#    'spatialCoverageDescription': 'Kosovo, Serbia',
#    'start': {'in': {'year': '0300'}, 'label': '1700 BP (2000)'},
#    'stop': {'in': {'year': '0564'}, 'label': '1436 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb662n6h': {'editorialNote': 'Derived from FASTI, but no match in 2004 dataset.',
#    'id': 'p0qhb662n6h',
#    'label': 'orientalizzante',
#    'language': 'ita-latn',
#    'localizedLabels': {'eng-latn': ['Orientalizing', 'Phoenician'],
#     'ita-latn': ['orientalizzante']},
#    'note': 'http://www.worldcat.org/oclc/175286417',
#    'spatialCoverageDescription': 'Sardinia',
#    'start': {'in': {'year': '-0730'}, 'label': '2730 BP (2000)'},
#    'stop': {'in': {'year': '-0581'}, 'label': '2581 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb662n84': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0rrjd9q9k3',
#    'id': 'p0qhb662n84',
#    'label': 'époque contemporaine',
#    'language': 'fra-latn',
#    'localizedLabels': {'eng-latn': ['Contemporary'],
#     'fra-latn': ['époque contemporaine']},
#    'note': 'INRAP',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/France',
#      'label': 'France'}],
#    'spatialCoverageDescription': 'France',
#    'start': {'in': {'year': '1800'}, 'label': '200 BP (2000)'},
#    'stop': {'in': {'year': '2000'}, 'label': '0 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb662qrr': {'editorialNote': 'no source provided',
#    'id': 'p0qhb662qrr',
#    'label': 'Mittelalter',
#    'language': 'deu-latn',
#    'localizedLabels': {'deu-latn': ['Mittelalter'], 'eng-latn': ['Medieval']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Germany',
#      'label': 'Germany'},
#     {'id': 'http://dbpedia.org/resource/Switzerland', 'label': 'Switzerland'},
#     {'id': 'http://dbpedia.org/resource/Czech_Republic',
#      'label': 'Czech Republic'},
#     {'id': 'http://dbpedia.org/resource/Liechtenstein',
#      'label': 'Liechtenstein'}],
#    'spatialCoverageDescription': 'Germany, Switzerland, Czech Republic, Liechtenstein',
#    'start': {'in': {'year': '0568'}, 'label': '1432 BP (2000)'},
#    'stop': {'in': {'year': '1499'}, 'label': '501 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb662r96': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w43hwk',
#    'id': 'p0qhb662r96',
#    'label': 'Paleolitico Medio',
#    'language': 'ita-latn',
#    'localizedLabels': {'eng-latn': ['Middle Paleolithic'],
#     'ita-latn': ['Paleolitico Medio']},
#    'spatialCoverageDescription': 'Italy less Sicily, Sardinia, Tuscany, Umbria',
#    'start': {'in': {'year': '-150000'}, 'label': '152000 BP (2000)'},
#    'stop': {'in': {'year': '-40001'}, 'label': '42001 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb662s3n': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w485jk',
#    'id': 'p0qhb662s3n',
#    'label': 'отомански',
#    'language': 'srp-cyrl',
#    'localizedLabels': {'eng-latn': ['Ottoman'], 'srp-cyrl': ['отомански']},
#    'spatialCoverageDescription': 'Kosovo, Serbia',
#    'start': {'in': {'year': '1389'}, 'label': '611 BP (2000)'},
#    'stop': {'in': {'year': '1849'}, 'label': '151 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb662s6j': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4nfqg',
#    'id': 'p0qhb662s6j',
#    'label': 'Bashkëkohore',
#    'language': 'als-latn',
#    'localizedLabels': {'als-latn': ['Bashkëkohore'],
#     'eng-latn': ['Contemporary']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Albania',
#      'label': 'Albania'}],
#    'spatialCoverageDescription': 'Albania',
#    'start': {'in': {'year': '1944'}, 'label': '56 BP (2000)'},
#    'stop': {'in': {'year': '2000'}, 'label': '0 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb662trj': {'editorialNote': 'Derived from Foundation of the Hellenic World, but no match in the 2000 dataset.',
#    'id': 'p0qhb662trj',
#    'label': 'Κατώτερη Παλαιολιθική',
#    'language': 'ell-latn',
#    'localizedLabels': {'ell-latn': ['Κατώτερη Παλαιολιθική'],
#     'eng-latn': ['Lower Paleolithic']},
#    'note': 'Foundation of the Hellenic World',
#    'spatialCoverageDescription': 'Crete',
#    'start': {'in': {'year': '-350000'}, 'label': '352000 BP (2000)'},
#    'stop': {'in': {'year': '-100001'}, 'label': '102001 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb662z9q': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0339m9n44g',
#    'id': 'p0qhb662z9q',
#    'label': 'Μέση Εποχή του Χαλκού',
#    'language': 'ell-latn',
#    'localizedLabels': {'ell-latn': ['Μέση Εποχή του Χαλκού'],
#     'eng-latn': ['Middle Bronze age']},
#    'note': 'Foundation of the Hellenic World',
#    'spatialCoverageDescription': 'Greece except Crete',
#    'start': {'in': {'year': '-2100'}, 'label': '4100 BP (2000)'},
#    'stop': {'in': {'year': '-1551'}, 'label': '3551 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb6633fn': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0339m9cqnj',
#    'id': 'p0qhb6633fn',
#    'label': 'υπομυκηναϊκή',
#    'language': 'ell-latn',
#    'localizedLabels': {'ell-latn': ['υπομυκηναϊκή'],
#     'eng-latn': ['Submycenaean']},
#    'note': 'Foundation of the Hellenic World',
#    'spatialCoverageDescription': 'Greece except Crete',
#    'start': {'in': {'year': '-1100'}, 'label': '3100 BP (2000)'},
#    'stop': {'in': {'year': '-1051'}, 'label': '3051 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66357d': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4bnsk',
#    'id': 'p0qhb66357d',
#    'label': 'Bronz i hershëm',
#    'language': 'als-latn',
#    'localizedLabels': {'als-latn': ['Bronz i hershëm'],
#     'eng-latn': ['Early Bronze Age']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Albania',
#      'label': 'Albania'}],
#    'spatialCoverageDescription': 'Albania',
#    'start': {'in': {'year': '-2100'}, 'label': '4100 BP (2000)'},
#    'stop': {'in': {'year': '-1801'}, 'label': '3801 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66358p': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0zj6g877vs',
#    'id': 'p0qhb66358p',
#    'label': 'Bronze Age',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Bronze Age']},
#    'note': 'ARENA1/ADS',
#    'spatialCoverageDescription': 'Norway',
#    'start': {'in': {'year': '-1800'}, 'label': '3800 BP (2000)'},
#    'stop': {'in': {'year': '-0501'}, 'label': '2501 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb6637v8': {'id': 'p0qhb6637v8',
#    'label': 'Frühes Neolithikum',
#    'language': 'deu-latn',
#    'localizedLabels': {'deu-latn': ['Frühes Neolithikum'],
#     'eng-latn': ['Early Neolithic']},
#    'note': 'Austrian Academy of Sciences',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Austria',
#      'label': 'Austria'}],
#    'spatialCoverageDescription': 'Austria',
#    'start': {'in': {'year': '-5600'}, 'label': '7600 BP (2000)'},
#    'stop': {'in': {'year': '-4801'}, 'label': '6801 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66388g': {'editorialNote': 'no source provided',
#    'id': 'p0qhb66388g',
#    'label': 'Spätmittelalter',
#    'language': 'deu-latn',
#    'localizedLabels': {'deu-latn': ['Spätmittelalter'],
#     'eng-latn': ['Late Medieval']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Germany',
#      'label': 'Germany'},
#     {'id': 'http://dbpedia.org/resource/Switzerland', 'label': 'Switzerland'},
#     {'id': 'http://dbpedia.org/resource/Czech_Republic',
#      'label': 'Czech Republic'},
#     {'id': 'http://dbpedia.org/resource/Liechtenstein',
#      'label': 'Liechtenstein'}],
#    'spatialCoverageDescription': 'Germany, Switzerland, Czech Republic, Liechtenstein',
#    'start': {'in': {'year': '1250'}, 'label': '750 BP (2000)'},
#    'stop': {'in': {'year': '1499'}, 'label': '501 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb6639xc': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4mwsq',
#    'id': 'p0qhb6639xc',
#    'label': 'Upper Paleolithic',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Upper Paleolithic']},
#    'spatialCoverageDescription': 'Tuscany, Umbria',
#    'start': {'in': {'year': '-40000'}, 'label': '42000 BP (2000)'},
#    'stop': {'in': {'year': '-10001'}, 'label': '12001 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb663g4t': {'editorialNote': 'no source provided',
#    'id': 'p0qhb663g4t',
#    'label': 'Mittleres Jungpaläolithikum',
#    'language': 'deu-latn',
#    'localizedLabels': {'deu-latn': ['Mittleres Jungpaläolithikum'],
#     'eng-latn': ['Middle Upper Paleolithic']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Germany',
#      'label': 'Germany'},
#     {'id': 'http://dbpedia.org/resource/Switzerland', 'label': 'Switzerland'},
#     {'id': 'http://dbpedia.org/resource/Czech_Republic',
#      'label': 'Czech Republic'},
#     {'id': 'http://dbpedia.org/resource/Liechtenstein',
#      'label': 'Liechtenstein'}],
#    'spatialCoverageDescription': 'Germany, Switzerland, Czech Republic, Liechtenstein',
#    'start': {'in': {'year': '-32500'}, 'label': '34500 BP (2000)'},
#    'stop': {'in': {'year': '-22501'}, 'label': '24501 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb663jcf': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4kg5w',
#    'id': 'p0qhb663jcf',
#    'label': 'Classical',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Classical']},
#    'spatialCoverageDescription': 'Tuscany, Umbria',
#    'start': {'in': {'year': '-0480'}, 'label': '2480 BP (2000)'},
#    'stop': {'in': {'year': '-0351'}, 'label': '2351 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb663nc7': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0rrjd9492t',
#    'id': 'p0qhb663nc7',
#    'label': 'Paléolithique moyen',
#    'language': 'fra-latn',
#    'localizedLabels': {'eng-latn': ['Middle Paleolithic'],
#     'fra-latn': ['Paléolithique moyen']},
#    'note': 'INRAP',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/France',
#      'label': 'France'}],
#    'spatialCoverageDescription': 'France',
#    'start': {'in': {'year': '-300000'}, 'label': '302000 BP (2000)'},
#    'stop': {'in': {'year': '-40001'}, 'label': '42001 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb663qtk': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4b3x6',
#    'id': 'p0qhb663qtk',
#    'label': 'цлассиц Илирски',
#    'language': 'srp-cyrl',
#    'localizedLabels': {'eng-latn': ['Classic IIllyrian', 'Urban illyrian'],
#     'srp-cyrl': ['цлассиц Илирски']},
#    'spatialCoverageDescription': 'Kosovo, Serbia',
#    'start': {'in': {'year': '-0480'}, 'label': '2480 BP (2000)'},
#    'stop': {'in': {'year': '-0337'}, 'label': '2337 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb663rsj': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4wpdc',
#    'id': 'p0qhb663rsj',
#    'label': 'Hekuri i hershëm',
#    'language': 'als-latn',
#    'localizedLabels': {'als-latn': ['Hekuri i hershëm'],
#     'eng-latn': ['Early Iron Age']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Albania',
#      'label': 'Albania'}],
#    'spatialCoverageDescription': 'Albania',
#    'start': {'in': {'year': '-1100'}, 'label': '3100 BP (2000)'},
#    'stop': {'in': {'year': '-0801'}, 'label': '2801 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb663svd': {'id': 'p0qhb663svd',
#    'label': 'Stormaktstiden',
#    'language': 'swe-latn',
#    'localizedLabels': {'eng-latn': ['Swedish Empire'],
#     'swe-latn': ['Stormaktstiden']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Sweden',
#      'label': 'Sweden'}],
#    'spatialCoverageDescription': 'Sweden',
#    'start': {'in': {'year': '1611'}, 'label': '389 BP (2000)'},
#    'stop': {'in': {'year': '1721'}, 'label': '279 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb663t2t': {'editorialNote': 'Derived from FASTI, but no match in the 2004 dataset.',
#    'id': 'p0qhb663t2t',
#    'label': 'starejša železna doba',
#    'language': 'slv-latn',
#    'localizedLabels': {'eng-latn': ['Early Iron Age'],
#     'slv-latn': ['starejša železna doba']},
#    'note': 'ZRC SAZU, Institute of Archaeology',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Slovenia',
#      'label': 'Slovenia'}],
#    'spatialCoverageDescription': 'Slovenia',
#    'start': {'in': {'year': '-0750'}, 'label': '2750 BP (2000)'},
#    'stop': {'in': {'year': '-0301'}, 'label': '2301 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb663tk9': {'id': 'p0qhb663tk9',
#    'label': 'kora újkor',
#    'language': 'hun-latn',
#    'localizedLabels': {'eng-latn': ['Early Modern Age'],
#     'hun-latn': ['kora újkor']},
#    'note': 'Hungarian National Museum',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Hungary',
#      'label': 'Hungary'}],
#    'spatialCoverageDescription': 'Hungary',
#    'start': {'in': {'year': '1526'}, 'label': '474 BP (2000)'},
#    'stop': {'in': {'year': '1710'}, 'label': '290 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb663wjh': {'id': 'p0qhb663wjh',
#    'label': 'Ältere Eisenzeit',
#    'language': 'deu-latn',
#    'localizedLabels': {'deu-latn': ['Ältere Eisenzeit'],
#     'eng-latn': ['Early Iron Age']},
#    'note': 'Austrian Academy of Sciences',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Austria',
#      'label': 'Austria'}],
#    'spatialCoverageDescription': 'Austria',
#    'start': {'in': {'year': '-0800'}, 'label': '2800 BP (2000)'},
#    'stop': {'in': {'year': '-0451'}, 'label': '2451 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb663wv6': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0kh9dsts5m',
#    'id': 'p0qhb663wv6',
#    'label': 'Upper Palaeolithic',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Upper Palaeolithic']},
#    'note': 'English Heritage Periods List',
#    'spatialCoverageDescription': 'Britain',
#    'start': {'in': {'year': '-40000'}, 'label': '42000 BP (2000)'},
#    'stop': {'in': {'year': '-10001'}, 'label': '12001 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb663z8n': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0vpm8v7f92',
#    'id': 'p0qhb663z8n',
#    'label': 'Tarda età del Bronzo',
#    'language': 'ita-latn',
#    'localizedLabels': {'eng-latn': ['Late Bronze Age'],
#     'ita-latn': ['Tarda età del Bronzo']},
#    'note': 'http://www.worldcat.org/oclc/39695441',
#    'spatialCoverageDescription': 'Sicily',
#    'start': {'in': {'year': '-1200'}, 'label': '3200 BP (2000)'},
#    'stop': {'in': {'year': '-0901'}, 'label': '2901 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb6642m4': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0339m9zc3z',
#    'id': 'p0qhb6642m4',
#    'label': 'Νεολιθική',
#    'language': 'ell-latn',
#    'localizedLabels': {'ell-latn': ['Νεολιθική'], 'eng-latn': ['Neolithic']},
#    'note': 'Foundation of the Hellenic World',
#    'spatialCoverageDescription': 'Greece except Crete',
#    'start': {'in': {'year': '-7000'}, 'label': '9000 BP (2000)'},
#    'stop': {'in': {'year': '-3201'}, 'label': '5201 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66433w': {'id': 'p0qhb66433w',
#    'label': 'Mittelalter',
#    'language': 'deu-latn',
#    'localizedLabels': {'deu-latn': ['Mittelalter'], 'eng-latn': ['Medieval']},
#    'note': 'Austrian Academy of Sciences',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Austria',
#      'label': 'Austria'}],
#    'spatialCoverageDescription': 'Austria',
#    'start': {'in': {'year': '0568'}, 'label': '1432 BP (2000)'},
#    'stop': {'in': {'year': '1499'}, 'label': '501 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb6643mc': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0339m9n7g7',
#    'id': 'p0qhb6643mc',
#    'label': 'Κατώτερη Παλαιολιθική',
#    'language': 'ell-latn',
#    'localizedLabels': {'ell-latn': ['Κατώτερη Παλαιολιθική'],
#     'eng-latn': ['Lower Paleolithic']},
#    'note': 'Foundation of the Hellenic World',
#    'spatialCoverageDescription': 'Greece except Crete',
#    'start': {'in': {'year': '-348000'}, 'label': '350000 BP (2000)'},
#    'stop': {'in': {'year': '-98001'}, 'label': '100001 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb6644mm': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4wh77',
#    'id': 'p0qhb6644mm',
#    'label': 'средна бронзова епоха',
#    'language': 'bul-cyrl',
#    'localizedLabels': {'bul-cyrl': ['средна бронзова епоха'],
#     'eng-latn': ['Middle Bronze Age']},
#    'note': 'National Institute of Archaeology with Museum, Automated Information System "Archaeological Map of Bulgaria"',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Bulgaria',
#      'label': 'Bulgaria'}],
#    'spatialCoverageDescription': 'Bulgaria',
#    'start': {'in': {'year': '-1900'}, 'label': '3900 BP (2000)'},
#    'stop': {'in': {'year': '-1601'}, 'label': '3601 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb6644wz': {'editorialNote': 'This period is derived from the aggregation of two periods in the 2004 Fasti Periodization: http://n2t.net/ark:/99152/p06v8w45j9q, http://n2t.net/ark:/99152/p06v8w4bf8s.',
#    'id': 'p0qhb6644wz',
#    'label': 'желязна епоха',
#    'language': 'bul-cyrl',
#    'localizedLabels': {'bul-cyrl': ['желязна епоха'],
#     'eng-latn': ['Iron Age']},
#    'note': 'National Institute of Archaeology with Museum, Automated Information System "Archaeological Map of Bulgaria"',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Bulgaria',
#      'label': 'Bulgaria'}],
#    'spatialCoverageDescription': 'Bulgaria',
#    'start': {'in': {'year': '-1100'}, 'label': '3100 BP (2000)'},
#    'stop': {'in': {'year': '0014'}, 'label': '1986 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664686': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0zj6g8zpn4',
#    'id': 'p0qhb664686',
#    'label': 'Neolithic',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Neolithic']},
#    'note': 'ARENA1/ADS',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Denmark',
#      'label': 'Denmark'}],
#    'spatialCoverageDescription': 'Denmark',
#    'start': {'in': {'year': '-3900'}, 'label': '5900 BP (2000)'},
#    'stop': {'in': {'year': '-1701'}, 'label': '3701 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66472n': {'editorialNote': 'Derived from Foundation of the Hellenic World, but no match in the 2000 dataset.',
#    'id': 'p0qhb66472n',
#    'label': 'Ελληνιστική',
#    'language': 'ell-latn',
#    'localizedLabels': {'ell-latn': ['Ελληνιστική'],
#     'eng-latn': ['Hellenistic']},
#    'note': 'Foundation of the Hellenic World',
#    'spatialCoverageDescription': 'Crete',
#    'start': {'in': {'year': '-0323'}, 'label': '2323 BP (2000)'},
#    'stop': {'in': {'year': '-0032'}, 'label': '2032 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb6648kc': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4qcqd',
#    'id': 'p0qhb6648kc',
#    'label': 'mezolitik',
#    'language': 'slv-latn',
#    'localizedLabels': {'eng-latn': ['Mesolithic'], 'slv-latn': ['mezolitik']},
#    'note': 'ZRC SAZU, Institute of Archaeology',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Slovenia',
#      'label': 'Slovenia'}],
#    'spatialCoverageDescription': 'Slovenia',
#    'start': {'in': {'year': '-8000'}, 'label': '10000 BP (2000)'},
#    'stop': {'in': {'year': '-5001'}, 'label': '7001 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664bgz': {'editorialNote': 'no source provided',
#    'id': 'p0qhb664bgz',
#    'label': 'Frühes Mittelalter',
#    'language': 'deu-latn',
#    'localizedLabels': {'deu-latn': ['Frühes Mittelalter'],
#     'eng-latn': ['Early Medieval']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Germany',
#      'label': 'Germany'},
#     {'id': 'http://dbpedia.org/resource/Switzerland', 'label': 'Switzerland'},
#     {'id': 'http://dbpedia.org/resource/Czech_Republic',
#      'label': 'Czech Republic'},
#     {'id': 'http://dbpedia.org/resource/Liechtenstein',
#      'label': 'Liechtenstein'}],
#    'spatialCoverageDescription': 'Germany, Switzerland, Czech Republic, Liechtenstein',
#    'start': {'in': {'year': '0568'}, 'label': '1432 BP (2000)'},
#    'stop': {'in': {'year': '0975'}, 'label': '1025 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664bxt': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0pqptcfq9t',
#    'id': 'p0qhb664bxt',
#    'label': 'Middeleeuwen',
#    'language': 'nld-latn',
#    'localizedLabels': {'eng-latn': ['Medieval'], 'nld-latn': ['Middeleeuwen']},
#    'note': 'Rijksdienst voor het Cultureel Erfgoed http://data.cultureelerfgoed.nl/semnet/4bf24a9f-1f7d-497e-96a4-d4a0f42d564b',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Netherlands',
#      'label': 'Netherlands'}],
#    'spatialCoverageDescription': 'Netherlands',
#    'start': {'in': {'year': '0450'}, 'label': '1550 BP (2000)'},
#    'stop': {'in': {'year': '1499'}, 'label': '501 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664f27': {'editorialNote': 'Derived from Foundation of the Hellenic World, but no match in the 2000 dataset.',
#    'id': 'p0qhb664f27',
#    'label': 'Κλασική',
#    'language': 'ell-latn',
#    'localizedLabels': {'ell-latn': ['Κλασική'], 'eng-latn': ['Classical']},
#    'note': 'Foundation of the Hellenic World',
#    'spatialCoverageDescription': 'Crete',
#    'start': {'in': {'year': '-0480'}, 'label': '2480 BP (2000)'},
#    'stop': {'in': {'year': '-0324'}, 'label': '2324 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664f99': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0kh9dsbm2h',
#    'id': 'p0qhb664f99',
#    'label': 'Middle Neolithic',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Middle Neolithic']},
#    'note': 'English Heritage Periods List',
#    'spatialCoverageDescription': 'Britain',
#    'start': {'in': {'year': '-3300'}, 'label': '5300 BP (2000)'},
#    'stop': {'in': {'year': '-2901'}, 'label': '4901 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664g3r': {'editorialNote': 'Derived from FASTI, but no match in 2004 dataset.',
#    'id': 'p0qhb664g3r',
#    'label': 'tardoantico',
#    'language': 'ita-latn',
#    'localizedLabels': {'eng-latn': ['Late Antique'],
#     'ita-latn': ['tardoantico']},
#    'spatialCoverageDescription': 'Sardinia',
#    'start': {'in': {'year': '0400'}, 'label': '1600 BP (2000)'},
#    'stop': {'in': {'year': '0599'}, 'label': '1401 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664gfq': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4ntkd',
#    'id': 'p0qhb664gfq',
#    'label': 'Late Antique',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Late Antique']},
#    'spatialCoverageDescription': 'Tuscany, Umbria',
#    'start': {'in': {'year': '0400'}, 'label': '1600 BP (2000)'},
#    'stop': {'in': {'year': '0599'}, 'label': '1401 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664gxv': {'editorialNote': 'Derived from INRAP, but no match in the 2007 dataset.',
#    'id': 'p0qhb664gxv',
#    'label': 'La Tène finale',
#    'language': 'fra-latn',
#    'localizedLabels': {'eng-latn': ['Final La Tène '],
#     'fra-latn': ['La Tène finale']},
#    'note': 'INRAP',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/France',
#      'label': 'France'}],
#    'spatialCoverageDescription': 'France',
#    'start': {'in': {'year': '-0150'}, 'label': '2150 BP (2000)'},
#    'stop': {'in': {'year': '-0051'}, 'label': '2051 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664h77': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4wpdc',
#    'id': 'p0qhb664h77',
#    'label': 'Hekuri i hershëm',
#    'language': 'als-latn',
#    'localizedLabels': {'als-latn': ['Hekuri i hershëm'],
#     'eng-latn': ['Iron Age']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Albania',
#      'label': 'Albania'}],
#    'spatialCoverageDescription': 'Albania',
#    'start': {'in': {'year': '-1100'}, 'label': '3100 BP (2000)'},
#    'stop': {'in': {'year': '-0601'}, 'label': '2601 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664hzf': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0vpm8v6dk5',
#    'id': 'p0qhb664hzf',
#    'label': 'Prima età del Bronzo',
#    'language': 'ita-latn',
#    'localizedLabels': {'eng-latn': ['Early Bronze Age'],
#     'ita-latn': ['Prima età del Bronzo']},
#    'note': 'http://www.worldcat.org/oclc/39695441',
#    'spatialCoverageDescription': 'Sicily',
#    'start': {'in': {'year': '-2500'}, 'label': '4500 BP (2000)'},
#    'stop': {'in': {'year': '-1201'}, 'label': '3201 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664pbd': {'editorialNote': 'Derived from FASTI, but no match in 2004 dataset.',
#    'id': 'p0qhb664pbd',
#    'label': 'Prima Età del Bronzo',
#    'language': 'ita-latn',
#    'localizedLabels': {'eng-latn': ['Early Bronze Age', 'Bonnanaro A'],
#     'ita-latn': ['Prima Età del Bronzo']},
#    'note': 'http://www.worldcat.org/oclc/175286417',
#    'spatialCoverageDescription': 'Sardinia',
#    'start': {'in': {'year': '-2200'}, 'label': '4200 BP (2000)'},
#    'stop': {'in': {'year': '-1901'}, 'label': '3901 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664q29': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0rrjd9g3sq',
#    'id': 'p0qhb664q29',
#    'label': 'Épipaléolithique',
#    'language': 'fra-latn',
#    'localizedLabels': {'eng-latn': ['EpiPaleolithic'],
#     'fra-latn': ['Épipaléolithique']},
#    'note': 'INRAP',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/France',
#      'label': 'France'}],
#    'spatialCoverageDescription': 'France',
#    'start': {'in': {'year': '-12500'}, 'label': '14500 BP (2000)'},
#    'stop': {'in': {'year': '-9601'}, 'label': '11601 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664q3k': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0pqptcpcb2',
#    'id': 'p0qhb664q3k',
#    'label': 'Vroege Middeleeuwen B',
#    'language': 'nld-latn',
#    'localizedLabels': {'eng-latn': ['Early Medieval B'],
#     'nld-latn': ['Vroege Middeleeuwen B']},
#    'note': 'Rijksdienst voor het Cultureel Erfgoed http://data.cultureelerfgoed.nl/semnet/98ffaf6a-e761-4d69-8c1c-e0d75646f3ba',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Netherlands',
#      'label': 'Netherlands'}],
#    'spatialCoverageDescription': 'Netherlands',
#    'start': {'in': {'year': '0525'}, 'label': '1475 BP (2000)'},
#    'stop': {'in': {'year': '0724'}, 'label': '1276 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664td2': {'editorialNote': 'Derived from Foundation of the Hellenic World, but no match in the 2000 dataset.',
#    'id': 'p0qhb664td2',
#    'label': 'Πρώιμη Γεωμετρική',
#    'language': 'ell-latn',
#    'localizedLabels': {'ell-latn': ['Πρώιμη Γεωμετρική'],
#     'eng-latn': ['Early Geometric']},
#    'note': 'Foundation of the Hellenic World',
#    'spatialCoverageDescription': 'Crete',
#    'start': {'in': {'year': '-0900'}, 'label': '2900 BP (2000)'},
#    'stop': {'in': {'year': '-0851'}, 'label': '2851 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664tfb': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4vpq4',
#    'id': 'p0qhb664tfb',
#    'label': 'модеран',
#    'language': 'srp-cyrl',
#    'localizedLabels': {'eng-latn': ['Modern'], 'srp-cyrl': ['модеран']},
#    'spatialCoverageDescription': 'Kosovo, Serbia',
#    'start': {'in': {'year': '1850'}, 'label': '150 BP (2000)'},
#    'stop': {'in': {'year': '1999'}, 'label': '1 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664tqp': {'id': 'p0qhb664tqp',
#    'label': 'Yngre vasatiden',
#    'language': 'swe-latn',
#    'localizedLabels': {'eng-latn': ['Late Vasa'],
#     'swe-latn': ['Yngre vasatiden']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Sweden',
#      'label': 'Sweden'}],
#    'spatialCoverageDescription': 'Sweden',
#    'start': {'in': {'year': '1611'}, 'label': '389 BP (2000)'},
#    'stop': {'in': {'year': '1654'}, 'label': '346 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664vm3': {'editorialNote': 'Derived from FASTI, but no match in 2004 dataset.',
#    'id': 'p0qhb664vm3',
#    'label': 'Primera Edad del Hierro',
#    'language': 'spa-latn',
#    'localizedLabels': {'eng-latn': ['Early Iron Age'],
#     'spa-latn': ['Primera Edad del Hierro']},
#    'note': 'Institute of Heritage Sciences, Spanish National Research Council (CSIC Incipit)',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Spain',
#      'label': 'Spain'}],
#    'spatialCoverageDescription': 'Spain',
#    'start': {'in': {'year': '-0800'}, 'label': '2800 BP (2000)'},
#    'stop': {'in': {'year': '-0401'}, 'label': '2401 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664vnc': {'editorialNote': 'Derived from FASTI, but no match in 2004 dataset.',
#    'id': 'p0qhb664vnc',
#    'label': 'Mesolitico',
#    'language': 'ita-latn',
#    'localizedLabels': {'eng-latn': ['Mesolithic'], 'ita-latn': ['Mesolitico']},
#    'spatialCoverageDescription': 'Sardinia',
#    'start': {'in': {'year': '-10000'}, 'label': '12000 BP (2000)'},
#    'stop': {'in': {'year': '-5001'}, 'label': '7001 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664wpw': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0kh9dskb4m',
#    'id': 'p0qhb664wpw',
#    'label': 'Mesolithic',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Mesolithic']},
#    'note': 'English Heritage Periods List',
#    'spatialCoverageDescription': 'Britain',
#    'start': {'in': {'year': '-10000'}, 'label': '12000 BP (2000)'},
#    'stop': {'in': {'year': '-4001'}, 'label': '6001 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb664xk9': {'editorialNote': 'no source provided',
#    'id': 'p0qhb664xk9',
#    'label': 'Römische',
#    'language': 'deu-latn',
#    'localizedLabels': {'deu-latn': ['Römische'], 'eng-latn': ['Roman']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Germany',
#      'label': 'Germany'},
#     {'id': 'http://dbpedia.org/resource/Switzerland', 'label': 'Switzerland'},
#     {'id': 'http://dbpedia.org/resource/Czech_Republic',
#      'label': 'Czech Republic'},
#     {'id': 'http://dbpedia.org/resource/Liechtenstein',
#      'label': 'Liechtenstein'}],
#    'spatialCoverageDescription': 'Germany, Switzerland, Czech Republic, Liechtenstein',
#    'start': {'in': {'year': '0000'}, 'label': '2000 BP (2000)'},
#    'stop': {'in': {'year': '0374'}, 'label': '1626 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66522k': {'editorialNote': 'Derived from FASTI, but no match in the 2004 dataset.',
#    'id': 'p0qhb66522k',
#    'label': 'pozna bronasta doba',
#    'language': 'slv-latn',
#    'localizedLabels': {'eng-latn': ['Urnfield period'],
#     'slv-latn': ['pozna bronasta doba']},
#    'note': 'ZRC SAZU, Institute of Archaeology',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Slovenia',
#      'label': 'Slovenia'}],
#    'spatialCoverageDescription': 'Slovenia',
#    'start': {'in': {'year': '-1000'}, 'label': '3000 BP (2000)'},
#    'stop': {'in': {'year': '-0751'}, 'label': '2751 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb6655tv': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0kh9dsqpzm',
#    'id': 'p0qhb6655tv',
#    'label': 'Middle Bronze Age',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Middle Bronze Age']},
#    'note': 'English Heritage Periods List',
#    'spatialCoverageDescription': 'Britain',
#    'start': {'in': {'year': '-1600'}, 'label': '3600 BP (2000)'},
#    'stop': {'in': {'year': '-1201'}, 'label': '3201 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb6656g6': {'id': 'p0qhb6656g6',
#    'label': 'Mittleres Jungpaläolithikum',
#    'language': 'deu-latn',
#    'localizedLabels': {'deu-latn': ['Mittleres Jungpaläolithikum'],
#     'eng-latn': ['Middle Upper Paleolithic']},
#    'note': 'Austrian Academy of Sciences',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Austria',
#      'label': 'Austria'}],
#    'spatialCoverageDescription': 'Austria',
#    'start': {'in': {'year': '-32500'}, 'label': '34500 BP (2000)'},
#    'stop': {'in': {'year': '-22501'}, 'label': '24501 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb6658gp': {'editorialNote': 'Derived from FASTI, but no match in 2004 dataset.',
#    'id': 'p0qhb6658gp',
#    'label': 'Neolítico Final',
#    'language': 'spa-latn',
#    'localizedLabels': {'eng-latn': ['Late Neolithic'],
#     'spa-latn': ['Neolítico Final']},
#    'note': 'Institute of Heritage Sciences, Spanish National Research Council (CSIC Incipit)',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Spain',
#      'label': 'Spain'}],
#    'spatialCoverageDescription': 'Spain',
#    'start': {'in': {'year': '-2700'}, 'label': '4700 BP (2000)'},
#    'stop': {'in': {'year': '-2301'}, 'label': '4301 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb6658kk': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4d6vw',
#    'id': 'p0qhb6658kk',
#    'label': 'Arkaike/Para qytetare ilire',
#    'language': 'als-latn',
#    'localizedLabels': {'als-latn': ['Arkaike/Para qytetare ilire'],
#     'eng-latn': ['Archaic Illyrian', 'Protourban Illyrian']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Albania',
#      'label': 'Albania'}],
#    'spatialCoverageDescription': 'Albania',
#    'start': {'in': {'year': '-0600'}, 'label': '2600 BP (2000)'},
#    'stop': {'in': {'year': '-0481'}, 'label': '2481 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb665959': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0kh9ds4hjq',
#    'id': 'p0qhb665959',
#    'label': 'Late Neolithic',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Late Neolithic']},
#    'note': 'English Heritage Periods List',
#    'spatialCoverageDescription': 'Britain',
#    'start': {'in': {'year': '-2900'}, 'label': '4900 BP (2000)'},
#    'stop': {'in': {'year': '-2601'}, 'label': '4601 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66596k': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4 This definition not found in FASTI, so linked to FASTI collection.',
#    'id': 'p0qhb66596k',
#    'label': 'Eneolitic Timpuriu',
#    'language': 'ron-latn',
#    'localizedLabels': {'eng-latn': ['Lower Eneolithic'],
#     'ron-latn': ['Eneolitic Timpuriu']},
#    'note': 'Romanian Academy',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Romania',
#      'label': 'Romania'}],
#    'spatialCoverageDescription': 'Romania',
#    'start': {'in': {'year': '-5000'}, 'label': '7000 BP (2000)'},
#    'stop': {'in': {'year': '-4601'}, 'label': '6601 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb6659nf': {'editorialNote': 'This period is derived from the aggregation of three periods in the 2004 Fasti Periodization: http://n2t.net/ark:/99152/p06v8w4742c, http://n2t.net/ark:/99152/p06v8w4wh77, http://n2t.net/ark:/99152/p06v8w4gt6f.',
#    'id': 'p0qhb6659nf',
#    'label': 'бронзова епоха',
#    'language': 'bul-cyrl',
#    'localizedLabels': {'bul-cyrl': ['бронзова епоха'],
#     'eng-latn': ['Bronze Age']},
#    'note': 'National Institute of Archaeology with Museum, Automated Information System "Archaeological Map of Bulgaria"',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Bulgaria',
#      'label': 'Bulgaria'}],
#    'spatialCoverageDescription': 'Bulgaria',
#    'start': {'in': {'year': '-3400'}, 'label': '5400 BP (2000)'},
#    'stop': {'in': {'year': '-1101'}, 'label': '3101 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb665b6t': {'editorialNote': 'Derived from FASTI, but no match in the 2004 dataset.',
#    'id': 'p0qhb665b6t',
#    'label': 'starejši neolitik',
#    'language': 'slv-latn',
#    'localizedLabels': {'eng-latn': ['Early Neolithic'],
#     'slv-latn': ['starejši neolitik']},
#    'note': 'ZRC SAZU, Institute of Archaeology',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Slovenia',
#      'label': 'Slovenia'}],
#    'spatialCoverageDescription': 'Slovenia',
#    'start': {'in': {'year': '-5000'}, 'label': '7000 BP (2000)'},
#    'stop': {'in': {'year': '-4001'}, 'label': '6001 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb665b9q': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0zj6g86hfw',
#    'id': 'p0qhb665b9q',
#    'label': 'Post Medieval',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Post Medieval', 'Post-Medieval']},
#    'note': 'ARENA1/ADS',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Poland',
#      'label': 'Poland'}],
#    'spatialCoverageDescription': 'Poland',
#    'start': {'in': {'year': '1250'}, 'label': '750 BP (2000)'},
#    'stop': {'in': {'year': '1499'}, 'label': '501 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb665crt': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4k7fh',
#    'id': 'p0qhb665crt',
#    'label': 'Epoca Migraţiilor',
#    'language': 'ron-latn',
#    'localizedLabels': {'eng-latn': ['Migrations'],
#     'ron-latn': ['Epoca Migraţiilor']},
#    'note': 'Romanian Academy',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Romania',
#      'label': 'Romania'}],
#    'spatialCoverageDescription': 'Romania',
#    'start': {'in': {'year': '0374'}, 'label': '1626 BP (2000)'},
#    'stop': {'in': {'year': '0799'}, 'label': '1201 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb665d53': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0rrjd9dtpt',
#    'id': 'p0qhb665d53',
#    'label': 'Mésolithique ancien',
#    'language': 'fra-latn',
#    'localizedLabels': {'eng-latn': ['Early Mesolithic'],
#     'fra-latn': ['Mésolithique ancien']},
#    'note': 'INRAP',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/France',
#      'label': 'France'}],
#    'spatialCoverageDescription': 'France',
#    'start': {'in': {'year': '-9600'}, 'label': '11600 BP (2000)'},
#    'stop': {'in': {'year': '-8301'}, 'label': '10301 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb665dff': {'editorialNote': 'Derived from Foundation of the Hellenic World, but no match in the 2000 dataset.',
#    'id': 'p0qhb665dff',
#    'label': 'Πρώιμη εποχή του Χαλκού',
#    'language': 'ell-latn',
#    'localizedLabels': {'ell-latn': ['Πρώιμη εποχή του Χαλκού'],
#     'eng-latn': ['Early Bronze age']},
#    'note': 'Foundation of the Hellenic World',
#    'spatialCoverageDescription': 'Crete',
#    'start': {'in': {'year': '-3200'}, 'label': '5200 BP (2000)'},
#    'stop': {'in': {'year': '-2101'}, 'label': '4101 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb665g8g': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4kcjp',
#    'id': 'p0qhb665g8g',
#    'label': 'Eneolitico',
#    'language': 'ita-latn',
#    'localizedLabels': {'eng-latn': ['Eneolithic', 'Copper Age'],
#     'ita-latn': ['Eneolitico']},
#    'spatialCoverageDescription': 'Italy less Sicily, Sardinia, Tuscany, Umbria',
#    'start': {'in': {'year': '-3300'}, 'label': '5300 BP (2000)'},
#    'stop': {'in': {'year': '-2301'}, 'label': '4301 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb665h5t': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0zj6g8m7nn',
#    'id': 'p0qhb665h5t',
#    'label': 'Medieval',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Medieval']},
#    'note': 'ARENA1/ADS',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Iceland',
#      'label': 'Iceland'}],
#    'spatialCoverageDescription': 'Iceland',
#    'start': {'in': {'year': '1100'}, 'label': '900 BP (2000)'},
#    'stop': {'in': {'year': '1599'}, 'label': '401 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb665nn2': {'editorialNote': 'Not noted in source, but ultimately derived from work of Alan Simmons at Akrotiri Aetokremnos.',
#    'id': 'p0qhb665nn2',
#    'label': 'Akrotiri',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Akrotiri']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Cyprus',
#      'label': 'Cyprus'}],
#    'spatialCoverageDescription': 'Cyprus',
#    'start': {'in': {'year': '-9300'}, 'label': '11300 BP (2000)'},
#    'stop': {'in': {'year': '-8801'}, 'label': '10801 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb665rjw': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0zj6g8wft6',
#    'id': 'p0qhb665rjw',
#    'label': 'Bronze Age',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Bronze Age']},
#    'note': 'ARENA1/ADS',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Poland',
#      'label': 'Poland'}],
#    'spatialCoverageDescription': 'Poland',
#    'start': {'in': {'year': '-1800'}, 'label': '3800 BP (2000)'},
#    'stop': {'in': {'year': '-0401'}, 'label': '2401 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb665rrp': {'editorialNote': 'Derived from FASTI, but no match in 2004 dataset.',
#    'id': 'p0qhb665rrp',
#    'label': 'arcaico',
#    'language': 'ita-latn',
#    'localizedLabels': {'eng-latn': ['Archaic'], 'ita-latn': ['arcaico']},
#    'spatialCoverageDescription': 'Sicily',
#    'start': {'in': {'year': '-0580'}, 'label': '2580 BP (2000)'},
#    'stop': {'in': {'year': '-0481'}, 'label': '2481 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb665tzz': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4kg5w',
#    'id': 'p0qhb665tzz',
#    'label': 'Classico',
#    'language': 'ita-latn',
#    'localizedLabels': {'eng-latn': ['Classical'], 'ita-latn': ['Classico']},
#    'spatialCoverageDescription': 'Italy less Sicily, Sardinia, Tuscany, Umbria',
#    'start': {'in': {'year': '-0480'}, 'label': '2480 BP (2000)'},
#    'stop': {'in': {'year': '-0351'}, 'label': '2351 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb665v45': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0zj6g886nr',
#    'id': 'p0qhb665v45',
#    'label': 'Palaeolithic',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Palaeolithic']},
#    'note': 'ARENA1/ADS',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Denmark',
#      'label': 'Denmark'}],
#    'spatialCoverageDescription': 'Denmark',
#    'start': {'in': {'year': '-12500'}, 'label': '14500 BP (2000)'},
#    'stop': {'in': {'year': '-9001'}, 'label': '11001 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb665vpv': {'editorialNote': 'Derived from Foundation of the Hellenic World, but no match in the 2000 dataset.',
#    'id': 'p0qhb665vpv',
#    'label': 'Νεολιθική',
#    'language': 'ell-latn',
#    'localizedLabels': {'ell-latn': ['Νεολιθική'], 'eng-latn': ['Neolithic']},
#    'note': 'Foundation of the Hellenic World',
#    'spatialCoverageDescription': 'Crete',
#    'start': {'in': {'year': '-6800'}, 'label': '8800 BP (2000)'},
#    'stop': {'in': {'year': '-3201'}, 'label': '5201 BP (2000)'},
#    'type': 'PeriodDefinition'},
# ...
#    'label': 'Eneolithic',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Eneolithic', 'Copper Age']},
#    'spatialCoverageDescription': 'Tuscany, Umbria',
#    'start': {'in': {'year': '-3300'}, 'label': '5300 BP (2000)'},
#    'stop': {'in': {'year': '-2301'}, 'label': '4301 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66xm8d': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0ff3dtsspk',
#    'id': 'p0qhb66xm8d',
#    'label': 'Hallstatt Iron Age',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Hallstatt Iron Age']},
#    'note': 'http://www.worldcat.org/oclc/46858003',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Germany',
#      'label': 'Germany'},
#     {'id': 'http://dbpedia.org/resource/Switzerland', 'label': 'Switzerland'},
#     {'id': 'http://dbpedia.org/resource/Czech_Republic',
#      'label': 'Czech Republic'},
#     {'id': 'http://dbpedia.org/resource/Liechtenstein',
#      'label': 'Liechtenstein'}],
#    'spatialCoverageDescription': 'Germany, Switzerland, Czech Republic, Liechtenstein',
#    'start': {'in': {'year': '-1200'}, 'label': '3200 BP (2000)'},
#    'stop': {'in': {'year': '-0481'}, 'label': '2481 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66xnj2': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0rrjd97zgz',
#    'id': 'p0qhb66xnj2',
#    'label': 'Moyen Âge classique',
#    'language': 'fra-latn',
#    'localizedLabels': {'eng-latn': ['Central Medieval'],
#     'fra-latn': ['Moyen Âge classique', 'Second Moyen Age']},
#    'note': 'INRAP',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/France',
#      'label': 'France'}],
#    'spatialCoverageDescription': 'France',
#    'start': {'in': {'year': '1000'}, 'label': '1000 BP (2000)'},
#    'stop': {'in': {'year': '1299'}, 'label': '701 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66xpqr': {'editorialNote': 'Derived from FASTI, but no match in 2004 dataset.',
#    'id': 'p0qhb66xpqr',
#    'label': 'Epipaleolitic',
#    'language': 'ron-latn',
#    'localizedLabels': {'eng-latn': ['EpiPaleolithic'],
#     'ron-latn': ['Epipaleolitic']},
#    'note': 'Romanian Academy',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Romania',
#      'label': 'Romania'}],
#    'spatialCoverageDescription': 'Romania',
#    'start': {'in': {'year': '-11300'}, 'label': '13300 BP (2000)'},
#    'stop': {'in': {'year': '-7501'}, 'label': '9501 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66xqgx': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0jtbzwjsrv',
#    'id': 'p0qhb66xqgx',
#    'label': 'Bronze Age',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Bronze Age']},
#    'note': 'Jamieson, 2007 (Ian Potter Museum exhibition)',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Cyprus',
#      'label': 'Cyprus'}],
#    'spatialCoverageDescription': 'Cyprus',
#    'start': {'in': {'year': '-2500'}, 'label': '4500 BP (2000)'},
#    'stop': {'in': {'year': '-1801'}, 'label': '3801 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66xsnx': {'editorialNote': 'Derived from FASTI, but no match in 2004 dataset.',
#    'id': 'p0qhb66xsnx',
#    'label': 'Età del Bronzo',
#    'language': 'ita-latn',
#    'localizedLabels': {'eng-latn': ['Bronze Age'],
#     'ita-latn': ['Età del Bronzo']},
#    'note': 'http://www.worldcat.org/oclc/175286417',
#    'spatialCoverageDescription': 'Sardinia',
#    'start': {'in': {'year': '-2200'}, 'label': '4200 BP (2000)'},
#    'stop': {'in': {'year': '-0851'}, 'label': '2851 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66xsxb': {'id': 'p0qhb66xsxb',
#    'label': 'Folkvandringstid',
#    'language': 'swe-latn',
#    'localizedLabels': {'eng-latn': ['Migration Period'],
#     'swe-latn': ['Folkvandringstid']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Sweden',
#      'label': 'Sweden'}],
#    'spatialCoverageDescription': 'Sweden',
#    'start': {'in': {'year': '0400'}, 'label': '1600 BP (2000)'},
#    'stop': {'in': {'year': '0550'}, 'label': '1450 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66xttp': {'id': 'p0qhb66xttp',
#    'label': 'honfoglalás kor',
#    'language': 'hun-latn',
#    'localizedLabels': {'eng-latn': ['Hungarian Conquest Period'],
#     'hun-latn': ['honfoglalás kor']},
#    'note': 'Hungarian National Museum',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Hungary',
#      'label': 'Hungary'}],
#    'spatialCoverageDescription': 'Hungary',
#    'start': {'in': {'year': '0885'}, 'label': '1115 BP (2000)'},
#    'stop': {'in': {'year': '0999'}, 'label': '1001 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66xzmx': {'editorialNote': 'Derived from FASTI, but no match in 2004 dataset.',
#    'id': 'p0qhb66xzmx',
#    'label': 'paleolitico',
#    'language': 'ita-latn',
#    'localizedLabels': {'eng-latn': ['Paleolithic'],
#     'ita-latn': ['paleolitico']},
#    'spatialCoverageDescription': 'Sicily',
#    'start': {'in': {'year': '-600000'}, 'label': '602000 BP (2000)'},
#    'stop': {'in': {'year': '-10001'}, 'label': '12001 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66z2vh': {'id': 'p0qhb66z2vh',
#    'label': 'Mittelpaläolithikum',
#    'language': 'deu-latn',
#    'localizedLabels': {'deu-latn': ['Mittelpaläolithikum'],
#     'eng-latn': ['Middle Paleolithic']},
#    'note': 'Austrian Academy of Sciences',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Austria',
#      'label': 'Austria'}],
#    'spatialCoverageDescription': 'Austria',
#    'start': {'in': {'year': '-298000'}, 'label': '300000 BP (2000)'},
#    'stop': {'in': {'year': '-41501'}, 'label': '43501 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66z2zd': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0ff3dtmpwd',
#    'id': 'p0qhb66z2zd',
#    'label': 'Hallstatt B',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Hallstatt B', 'Urnfield period']},
#    'note': 'http://www.worldcat.org/oclc/46858003',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Germany',
#      'label': 'Germany'},
#     {'id': 'http://dbpedia.org/resource/Switzerland', 'label': 'Switzerland'},
#     {'id': 'http://dbpedia.org/resource/Czech_Republic',
#      'label': 'Czech Republic'},
#     {'id': 'http://dbpedia.org/resource/Liechtenstein',
#      'label': 'Liechtenstein'}],
#    'spatialCoverageDescription': 'Germany, Switzerland, Czech Republic, Liechtenstein',
#    'start': {'in': {'year': '-1000'}, 'label': '3000 BP (2000)'},
#    'stop': {'in': {'year': '-0751'}, 'label': '2751 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66z32x': {'id': 'p0qhb66z32x',
#    'label': 'Senmodern tid',
#    'language': 'swe-latn',
#    'localizedLabels': {'eng-latn': ['Contemporary'],
#     'swe-latn': ['Senmodern tid']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Sweden',
#      'label': 'Sweden'}],
#    'spatialCoverageDescription': 'Sweden',
#    'start': {'in': {'year': '1789'}, 'label': '211 BP (2000)'},
#    'stop': {'in': {'year': '2000'}, 'label': '0 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66z499': {'editorialNote': 'Derived from Foundation of the Hellenic World, but no match in the 2000 dataset.',
#    'id': 'p0qhb66z499',
#    'label': 'Ύστερη Γεωμετρική',
#    'language': 'ell-latn',
#    'localizedLabels': {'ell-latn': ['Ύστερη Γεωμετρική'],
#     'eng-latn': ['Late Geometric']},
#    'note': 'Foundation of the Hellenic World',
#    'spatialCoverageDescription': 'Crete',
#    'start': {'in': {'year': '-0760'}, 'label': '2760 BP (2000)'},
#    'stop': {'in': {'year': '-0701'}, 'label': '2701 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66z4gr': {'editorialNote': 'Derived from FASTI, but no match in 2004 dataset.',
#    'id': 'p0qhb66z4gr',
#    'label': 'Edad del Bronce Media',
#    'language': 'spa-latn',
#    'localizedLabels': {'eng-latn': ['Middle Bronze Age'],
#     'spa-latn': ['Edad del Bronce Media']},
#    'note': 'Institute of Heritage Sciences, Spanish National Research Council (CSIC Incipit)',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Spain',
#      'label': 'Spain'}],
#    'spatialCoverageDescription': 'Spain',
#    'start': {'in': {'year': '-1700'}, 'label': '3700 BP (2000)'},
#    'stop': {'in': {'year': '-1201'}, 'label': '3201 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66z5xv': {'id': 'p0qhb66z5xv',
#    'label': 'Modern tid',
#    'language': 'swe-latn',
#    'localizedLabels': {'eng-latn': ['Modern'], 'swe-latn': ['Modern tid']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Sweden',
#      'label': 'Sweden'}],
#    'spatialCoverageDescription': 'Sweden',
#    'start': {'in': {'year': '1521'}, 'label': '479 BP (2000)'},
#    'stop': {'in': {'year': '2000'}, 'label': '0 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66zbns': {'editorialNote': 'Derived from FASTI, but no match in the 2004 dataset.',
#    'id': 'p0qhb66zbns',
#    'label': 'srednji neolitik',
#    'language': 'slv-latn',
#    'localizedLabels': {'eng-latn': ['Middle Neolithic'],
#     'slv-latn': ['srednji neolitik']},
#    'note': 'ZRC SAZU, Institute of Archaeology',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Slovenia',
#      'label': 'Slovenia'}],
#    'spatialCoverageDescription': 'Slovenia',
#    'start': {'in': {'year': '-4000'}, 'label': '6000 BP (2000)'},
#    'stop': {'in': {'year': '-3501'}, 'label': '5501 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66zbrp': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0pqptct727',
#    'id': 'p0qhb66zbrp',
#    'label': 'Vroege Middeleeuwen C',
#    'language': 'nld-latn',
#    'localizedLabels': {'eng-latn': ['Early Medieval C'],
#     'nld-latn': ['Vroege Middeleeuwen C']},
#    'note': 'Rijksdienst voor het Cultureel Erfgoed http://data.cultureelerfgoed.nl/semnet/286fb38b-a368-45aa-97f3-8151d5bbc7f6',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Netherlands',
#      'label': 'Netherlands'}],
#    'spatialCoverageDescription': 'Netherlands',
#    'start': {'in': {'year': '0725'}, 'label': '1275 BP (2000)'},
#    'stop': {'in': {'year': '0899'}, 'label': '1101 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66zbsz': {'id': 'p0qhb66zbsz',
#    'label': 'népvándorlás kor',
#    'language': 'hun-latn',
#    'localizedLabels': {'eng-latn': ['Migration Period'],
#     'hun-latn': ['népvándorlás kor']},
#    'note': 'Hungarian National Museum',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Hungary',
#      'label': 'Hungary'}],
#    'spatialCoverageDescription': 'Hungary',
#    'start': {'in': {'year': '0400'}, 'label': '1600 BP (2000)'},
#    'stop': {'in': {'year': '0884'}, 'label': '1116 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66zc67': {'id': 'p0qhb66zc67',
#    'label': 'késő vaskor',
#    'language': 'hun-latn',
#    'localizedLabels': {'eng-latn': ['Late Iron Age'],
#     'hun-latn': ['késő vaskor']},
#    'note': 'Hungarian National Museum',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Hungary',
#      'label': 'Hungary'}],
#    'spatialCoverageDescription': 'Hungary',
#    'start': {'in': {'year': '-0450'}, 'label': '2450 BP (2000)'},
#    'stop': {'in': {'year': '-0101'}, 'label': '2101 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66zdzz': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0pqptckfbt',
#    'id': 'p0qhb66zdzz',
#    'label': 'Vroeg Mesolithicum',
#    'language': 'nld-latn',
#    'localizedLabels': {'eng-latn': ['Early Mesolithic'],
#     'nld-latn': ['Vroeg Mesolithicum']},
#    'note': 'Rijksdienst voor het Cultureel Erfgoed http://data.cultureelerfgoed.nl/semnet/6009967f-59c9-4e25-8268-4711c3c07235',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Netherlands',
#      'label': 'Netherlands'}],
#    'spatialCoverageDescription': 'Netherlands',
#    'start': {'in': {'year': '-8800'}, 'label': '10800 BP (2000)'},
#    'stop': {'in': {'year': '-7101'}, 'label': '9101 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66zjwf': {'id': 'p0qhb66zjwf',
#    'label': 'késő neolitikum',
#    'language': 'hun-latn',
#    'localizedLabels': {'eng-latn': ['Late Neolithic'],
#     'hun-latn': ['késő neolitikum']},
#    'note': 'Hungarian National Museum',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Hungary',
#      'label': 'Hungary'}],
#    'spatialCoverageDescription': 'Hungary',
#    'start': {'in': {'year': '-5000'}, 'label': '7000 BP (2000)'},
#    'stop': {'in': {'year': '-4501'}, 'label': '6501 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66zkft': {'editorialNote': 'no source provided',
#    'id': 'p0qhb66zkft',
#    'label': 'Spätpaläolithikum',
#    'language': 'deu-latn',
#    'localizedLabels': {'deu-latn': ['Spätpaläolithikum'],
#     'eng-latn': ['Late Palaeolithic']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Germany',
#      'label': 'Germany'},
#     {'id': 'http://dbpedia.org/resource/Switzerland', 'label': 'Switzerland'},
#     {'id': 'http://dbpedia.org/resource/Czech_Republic',
#      'label': 'Czech Republic'},
#     {'id': 'http://dbpedia.org/resource/Liechtenstein',
#      'label': 'Liechtenstein'}],
#    'spatialCoverageDescription': 'Germany, Switzerland, Czech Republic, Liechtenstein',
#    'start': {'in': {'year': '-11950'}, 'label': '13950 BP (2000)'},
#    'stop': {'in': {'year': '-9551'}, 'label': '11551 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66zmtc': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0vpm8v5gds',
#    'id': 'p0qhb66zmtc',
#    'label': 'Tarda età del Ferro',
#    'language': 'ita-latn',
#    'localizedLabels': {'eng-latn': ['Late Iron Age', 'Iron Age II'],
#     'ita-latn': ['Tarda età del Ferro']},
#    'note': 'http://www.worldcat.org/oclc/39695441',
#    'spatialCoverageDescription': 'Sicily',
#    'start': {'in': {'year': '-0734'}, 'label': '2734 BP (2000)'},
#    'stop': {'in': {'year': '-0581'}, 'label': '2581 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66zmzj': {'id': 'p0qhb66zmzj',
#    'label': 'Järnålder',
#    'language': 'swe-latn',
#    'localizedLabels': {'eng-latn': ['Iron Age'], 'swe-latn': ['Järnålder']},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Sweden',
#      'label': 'Sweden'}],
#    'spatialCoverageDescription': 'Sweden',
#    'start': {'in': {'year': '-0500'}, 'label': '2500 BP (2000)'},
#    'stop': {'in': {'year': '1050'}, 'label': '950 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66zp6j': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p06v8w4z7d2',
#    'id': 'p0qhb66zp6j',
#    'label': 'Mesolithic',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Mesolithic']},
#    'spatialCoverageDescription': 'Tuscany, Umbria',
#    'start': {'in': {'year': '-10000'}, 'label': '12000 BP (2000)'},
#    'stop': {'in': {'year': '-5001'}, 'label': '7001 BP (2000)'},
#    'type': 'PeriodDefinition'},
#   'p0qhb66zrdt': {'editorialNote': 'Derived from http://n2t.net/ark:/99152/p0rrjd9fmjb',
#    'id': 'p0qhb66zrdt',
#    'label': 'premier âge du Fer',
#    'language': 'fra-latn',
#    'localizedLabels': {'eng-latn': ['Early Iron age', 'Hallstat'],
#     'fra-latn': ['premier âge du Fer']},
#    'note': 'INRAP',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/France',
#      'label': 'France'}],
#    'spatialCoverageDescription': 'France',
#    'start': {'in': {'year': '-0800'}, 'label': '2800 BP (2000)'},
#    'stop': {'in': {'year': '-0451'}, 'label': '2451 BP (2000)'},
#    'type': 'PeriodDefinition'}},
#  'editorialNote': 'Periodizations gathered from ARIADNE partners on the national level in a series of EU countries, as well as periodizations from some non-EU Fasti Online contributors. Some of the definitions are derived from other PeriodO collections; where this is the case, a note has been included with the PeriodO URI of the definition from which it is derived.',
#  'id': 'p0qhb66',
#  'source': {'citation': 'ARIADNE Consortium. "ARIADNE Data Collection". 2015. http://www.ariadne-infrastructure.eu/Resources/PeriodO/documentation.',
#   'contributors': [{'name': ''}],
#   'creators': [{'name': 'ARIADNE Consortium'}],
#   'title': 'ARIADNE Data Collection',
#   'url': 'http://www.ariadne-infrastructure.eu/Resources/PeriodO/documentation',
#   'yearPublished': '2015'},
#  'type': 'PeriodCollection'}

# %%
# number of definitions
__builtin__.sum([len(v['definitions']) for v in rdata['periodCollections'].values() ])
# Out:
# 5466

# %%
for (k,v) in rdata['periodCollections'].items():
    print (k, len(v['definitions']))
# Out:
# p08p8mm 0
# p0qhb66 660
# p0pf2qb 40
# p0bsjms 1
# p0zmdxz 9
# p0znh3t 4
# p0244q7 1
# p08nrfc 5
# p0pp7vz 3
# p086kj9 522
# p0jf288 20
# p0dntkb 3
# p047fhm 27
# p0qwjcd 11
# p0dfzs7 1
# p0sgtfr 1
# p0339m9 53
# p0qwcp6 6
# p0v28d2 1
# p03tqbz 2
# p0ctc35 9
# p02sht9 3
# p044mt9 3
# p0r2jnt 1
# p0mwsd7 1
# p0mn2nd 29
# p0kh9ds 42
# p0kgptq 4
# p0pk6sc 1
# p0z3skm 26
# p08m57h 944
# p0qp9rs 55
# p0rrjd9 32
# p02q72z 2
# p0367jz 6
# p03wskd 116
# p0trc5r 5
# p05n4hj 11
# p0vhct4 13
# p0cmdf9 4
# p0j5frx 4
# p0ms2ch 5
# p0tns5v 7
# p0vn2fr 32
# p0pf7xr 10
# p0dg76f 42
# p07h9k6 30
# p0pqptc 53
# p08x7cz 2
# p077fc5 4
# p0rqpwq 4
# p0s7jn8 2
# p0cp447 11
# p0m63nj 108
# p0kc8t6 8
# p0r8d9c 95
# p0z5nvh 35
# p0f65r2 27
# p0wf3wd 13
# p03tcss 6
# p05xnzq 3
# p08tf6p 19
# p0d39r7 1
# p0fp7wv 52
# p0bd664 21
# p0c3bh8 5
# p0vm8tz 4
# p0dhmkc 2
# p0ff3dt 17
# p0jrrjb 26
# p0wnvm4 1
# p0gjgrs 31
# p0vrf7b 1
# p06v8w4 212
# p0323gx 5
# p089gcf 11
# p083p5r 63
# p09xsbn 4
# p0m9pcg 13
# p0pv57g 18
# p0fh3zc 2
# p06xc6m 2
# p03377f 2
# p05hrsf 57
# p06ptzs 1
# p0hrtx5 1
# p0k7ktv 1
# p0zj6g8 48
# p0vpm8v 13
# p0wswdm 3
# p044n25 6
# p0hvcwr 1
# p0jtbzw 31
# p06c6g3 1463
# p0dfxxp 5
# p0njrb4 10
# p0ccnvb 12
# p0swbsk 2
# p064v7m 13
# p077pzf 15
# p0qk76z 35
# p05krdx 31
# p08h8hs 3
# p0cfv7g 12
# p0pt6d8 3
# p0kj6dj 10

# %%
rdata['periodCollections']['p0bsjms']
# Out:
# {'definitions': {'p0bsjms2dzb': {'id': 'p0bsjms2dzb',
#    'label': 'Republican',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Republican']},
#    'note': 'Beginning-date corresponds with the end of the Celtiberian wars; outside of the Celtiberian homeland, the Republican period in Spain begins 218 B.C. (Second Punic War).',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Spain',
#      'label': 'Spain'}],
#    'spatialCoverageDescription': 'Spain',
#    'start': {'in': {'year': '-0132'}, 'label': '133 B.C.'},
#    'stop': {'in': {'year': '-0026'}, 'label': '27 B.C.'},
#    'type': 'PeriodDefinition'}},
#  'id': 'p0bsjms',
#  'source': {'locator': 'pages 3, 52',
#   'partOf': {'creators': [{'id': 'http://viaf.org/viaf/17271321',
#      'name': 'Curchin, Leonard A., 1950-'}],
#    'id': 'http://www.worldcat.org/oclc/51937089',
#    'title': 'The romanization of central Spain : complexity, diversity, and change in a provincial hinterland',
#    'yearPublished': 2004}},
#  'type': 'PeriodCollection'}

# %%
def definitions_from_file(data_path):
    rdata = json.load(open(data_path))
    for v in rdata['periodCollections'].values():
        for definition in v['definitions'].values():
            yield {
                'id':definition['id'],
                'language': definition['language'], 
                'label':definition['label'],
                'start': definition['start'].get('in', {}).get('year'),
                'stop':definition['stop'].get('in', {}).get('year'),
                'spatialCoverageDescription':definition.get('spatialCoverageDescription'),
                'len_spatialCoverage': len(definition.get('spatialCoverage', [])) # definition.get('spatialCoverage', {}).get('label')
            }

# %%
len(list(islice(definitions_from_file(DATA_PATH), None)))
# Out:
# 5466

# %%
list(islice(definitions_from_file(DATA_PATH), 10))
# Out:
# [{'id': 'p0qhb668r3q',
#   'label': 'ранна римска епоха',
#   'language': 'bul-cyrl',
#   'len_spatialCoverage': 1,
#   'spatialCoverageDescription': 'Bulgaria',
#   'start': '0015',
#   'stop': '0283'},
#  {'id': 'p0qhb66k7q6',
#   'label': 'Μέση Μινωική',
#   'language': 'ell-latn',
#   'len_spatialCoverage': 0,
#   'spatialCoverageDescription': 'Crete',
#   'start': '-1700',
#   'stop': '-1071'},
#  {'id': 'p0qhb663g4t',
#   'label': 'Mittleres Jungpaläolithikum',
#   'language': 'deu-latn',
#   'len_spatialCoverage': 4,
#   'spatialCoverageDescription': 'Germany, Switzerland, Czech Republic, Liechtenstein',
#   'start': '-32500',
#   'stop': '-22501'},
#  {'id': 'p0qhb66dbmx',
#   'label': 'Geometric (Cypro-Geometric) II',
#   'language': 'eng-latn',
#   'len_spatialCoverage': 1,
#   'spatialCoverageDescription': 'Cyprus',
#   'start': '-0950',
#   'stop': '-0851'},
#  {'id': 'p0qhb66wkxj',
#   'label': 'римскиот период',
#   'language': 'mkd-cyrl',
#   'len_spatialCoverage': 1,
#   'spatialCoverageDescription': 'Macedonia',
#   'start': '0030',
#   'stop': '0299'},
#  {'id': 'p0qhb66zbns',
#   'label': 'srednji neolitik',
#   'language': 'slv-latn',
#   'len_spatialCoverage': 1,
#   'spatialCoverageDescription': 'Slovenia',
#   'start': '-4000',
#   'stop': '-3501'},
#  {'id': 'p0qhb66x582',
#   'label': 'Παλαιολιθική',
#   'language': 'ell-latn',
#   'len_spatialCoverage': 0,
#   'spatialCoverageDescription': 'Greece except Crete',
#   'start': '-600000',
#   'stop': '-11001'},
#  {'id': 'p0qhb66xdn4',
#   'label': 'kora vaskor',
#   'language': 'hun-latn',
#   'len_spatialCoverage': 1,
#   'spatialCoverageDescription': 'Hungary',
#   'start': '-0900',
#   'stop': '-0701'},
#  {'id': 'p0qhb66pgtj',
#   'label': 'Spätmittelalter',
#   'language': 'deu-latn',
#   'len_spatialCoverage': 1,
#   'spatialCoverageDescription': 'Austria',
#   'start': '1250',
#   'stop': '1499'},
#  {'id': 'p0qhb66jx9k',
#   'label': 'Mittlere Kupferzeit',
#   'language': 'deu-latn',
#   'len_spatialCoverage': 1,
#   'spatialCoverageDescription': 'Austria',
#   'start': '-3400',
#   'stop': '-3001'}]

# %%
ddf = DataFrame(list(islice(definitions_from_file(DATA_PATH), None)))
ddf.head()
# Out:
#             id                           label  language  len_spatialCoverage  \
# 0  p0qhb668r3q              ранна римска епоха  bul-cyrl                    1
# 1  p0qhb66k7q6                    Μέση Μινωική  ell-latn                    0
# 2  p0qhb663g4t     Mittleres Jungpaläolithikum  deu-latn                    4
# 3  p0qhb66dbmx  Geometric (Cypro-Geometric) II  eng-latn                    1
# 4  p0qhb66wkxj                 римскиот период  mkd-cyrl                    1
#
#                           spatialCoverageDescription   start    stop
# 0                                           Bulgaria    0015    0283
# 1                                              Crete   -1700   -1071
# 2  Germany, Switzerland, Czech Republic, Liechten...  -32500  -22501
# 3                                             Cyprus   -0950   -0851
# 4                                          Macedonia    0030    0299

# %%
ddf.spatialCoverageDescription.value_counts()
# Out:
# Cyprus                                                                                              147
# Iowa                                                                                                140
# France                                                                                              135
# Denmark                                                                                             130
# China                                                                                               125
# Netherlands                                                                                         125
# Florida                                                                                             123
# Sweden                                                                                              106
# Crete                                                                                                87
# United Kingdom                                                                                       83
# Egypt                                                                                                72
# Greece                                                                                               71
# Spain                                                                                                70
# Rome                                                                                                 70
# Romania                                                                                              66
# Great Britain                                                                                        65
# Kentucky                                                                                             61
# Virginia                                                                                             59
# Bulgaria                                                                                             58
# Aegean                                                                                               55
# Albania                                                                                              54
# Slovenia                                                                                             48
# Roman Empire                                                                                         46
# Austria                                                                                              45
# Hungary                                                                                              45
# Poland                                                                                               44
# Sicily                                                                                               42
# Germany                                                                                              42
# Byzantine Empire                                                                                     42
# Holy Roman Empire                                                                                    41
#                                                                                                    ...
# Alagoas (Brazil)                                                                                      1
# Mycenae, Crete, Greece                                                                                1
# Jazira and Syria                                                                                      1
# Mosul; Ayyubid territory in the Jazira                                                                1
# Côte d'Ivoire                                                                                         1
# France, Great Britain, Turkey, Russia                                                                 1
# Cambodia                                                                                              1
# Argeș (Romania : Județ)                                                                               1
# Corinth                                                                                               1
# Caledonia, Ireland                                                                                    1
# Suse                                                                                                  1
# Near East and Greece                                                                                  1
# Khurasan, Afghanistan, northern India                                                                 1
# Europe, Near East                                                                                     1
# Wilhelmshaven (Germany)                                                                               1
# Ohio, Illinois, Missouri, Mississippi Valley region of the United States                              1
# Vicenza (Italy:Province)                                                                              1
# Etrurien                                                                                              1
# Bahrain, Tarut and Failaka, and the neighbouring region of the eastern Arabian coast                  1
# Mespotamia, Anatolia, the Levant, Persia                                                              1
# Japan, Russia                                                                                         1
# Uruk, southern Mesopotamia                                                                            1
# Khurasan; Baghdad; Iraq                                                                               1
# Sumer, Akkad, northern Levant, eastern Anatolia, Zagros                                               1
# Venice (Italy)                                                                                        1
# Eastern Anatolia                                                                                      1
# Abkhazia                                                                                              1
# Persia, Syria, Phoenicia, Asia Minor                                                                  1
# Afghanistan north of the Hindu Kush, Central Asian Amu Darya region of Uzbekistan and Tajikistan      1
# St Vincent                                                                                            1
# Name: spatialCoverageDescription, Length: 649, dtype: int64

# %%
ddf[ddf.spatialCoverageDescription == 'Cyprus']
# Out:
#                id                                   label  language  \
# 3     p0qhb66dbmx          Geometric (Cypro-Geometric) II  eng-latn
# 20    p0qhb666hmw                                 Ottoman  eng-latn
# 23    p0qhb66xqgx                              Bronze Age  eng-latn
# 26    p0qhb66n37f           Geometric (Cypro-Geometric) I  eng-latn
# 32    p0qhb66r5d4                       Middle Bronze Age  eng-latn
# 58    p0qhb66t6qg                                  Modern  eng-latn
# 126   p0qhb66b5bt                        Early Bronze Age  eng-latn
# 143   p0qhb66nkmb                         Proto-Neolithic  eng-latn
# 167   p0qhb667z6x               Archaic (Cypro-Archaic) I  eng-latn
# 199   p0qhb665nn2                                Akrotiri  eng-latn
# 316   p0qhb66jgcs                                 Roman I  eng-latn
# 328   p0qhb66s9kt                                Crusader  eng-latn
# 351   p0qhb66c264                           Hellenistic I  eng-latn
# 377   p0qhb66vvth                            Chalcolithic  eng-latn
# 397   p0qhb66tqmg              Archaic (Cypro-Archaic) II  eng-latn
# 411   p0qhb66vntx                         Late Bronze Age  eng-latn
# 422   p0qhb6695jd         Geometric (Cypro-Geometric) III  eng-latn
# 435   p0qhb66mrrk                               Byzantine  eng-latn
# 460   p0qhb66kdzj                          Hellenistic II  eng-latn
# 490   p0qhb666vcf                               Neolithic  eng-latn
# 516   p0qhb66qrwf                                Roman II  eng-latn
# 528   p0qhb66nbcf           Classical (Cypro-Classical) I  eng-latn
# 562   p0qhb66gn5v                                Venetian  eng-latn
# 647   p0qhb66s7vp          Classical (Cypro-Classical) II  eng-latn
# 1616  p08m57hwkmv                           Early Cypriot  eng-latn
# 1650  p08m57hq6sd                         Cypro-Geometric  eng-latn
# 1886  p08m57hgrmh                            Late Cypriot  eng-latn
# 2177  p08m57h6tvb                          Middle Cypriot  eng-latn
# 2735  p0dg76fcnx9                            Early Modern  eng-latn
# 2736  p0dg76fgh5d                          Present Modern  eng-latn
# ...           ...                                     ...       ...
# 3829  p0jtbzwrxbm                         Proto-Neolithic  eng-latn
# 3830  p0jtbzw932g         Geometric (Cypro-Geometric) III  eng-latn
# 3831  p0jtbzww6pr                          Hellenistic II  eng-latn
# 3832  p0jtbzwfv22     Late Bronze Age (Late Cypriot) IIIB  eng-latn
# 3833  p0jtbzwfmq9      Late Bronze Age (Late Cypriot) IIB  eng-latn
# 3834  p0jtbzwgxd7           Classical (Cypro-Classical) I  eng-latn
# 3835  p0jtbzw8gr5           Geometric (Cypro-Geometric) I  eng-latn
# 3836  p0jtbzwr3rh          Classical (Cypro-Classical) II  eng-latn
# 3837  p0jtbzwmmjw                           Hellenistic I  eng-latn
# 3838  p0jtbzw6f7b      Late Bronze Age (Late Cypriot) IIA  eng-latn
# 3839  p0jtbzw8xcb              Archaic (Cypro-Archaic) II  eng-latn
# 3840  p0jtbzw9jwb                                Iron Age  eng-latn
# 3841  p0jtbzwxgdq                               Neolithic  eng-latn
# 3842  p0jtbzwf4x5                                Roman II  eng-latn
# 3843  p0jtbzwhwbh           Transitional (Philia Culture)  eng-latn
# 3844  p0jtbzw33x8       Late Bronze Age (Late Cypriot) IB  eng-latn
# 3845  p0jtbzw727b  Middle Bronze Age (Middle Cypriot) III  eng-latn
# 3846  p0jtbzw3p99    Middle Bronze Age (Middle Cypriot) I  eng-latn
# 3847  p0jtbzwr5gf      Early Bronze Age (Early Cypriot) I  eng-latn
# 3848  p0jtbzwtk9t     Late Bronze Age (Late Cypriot) IIIC  eng-latn
# 3849  p0jtbzwkp48       Late Bronze Age (Late Cypriot) IA  eng-latn
# 3850  p0jtbzwt8d6     Early Bronze Age (Early Cypriot) II  eng-latn
# 3851  p0jtbzwwmnz      Late Bronze Age (Late Cypriot) IIC  eng-latn
# 3872  p06c6g3576d                    Cyprus Crisis, 1974-  eng-latn
# 4267  p06c6g32mpq                 Turkish rule, 1571-1878  eng-latn
# 4429  p06c6g3rpqz             Lusignan dynasty, 1192-1474  eng-latn
# 4821  p06c6g3g94b    War for Union with Greece, 1955-1959  eng-latn
# 4823  p06c6g3xt3s                Venetian rule, 1474-1570  eng-latn
# 5059  p06c6g3ck25             Turkish Conquest, 1570-1571  eng-latn
# 5091  p06c6g3ckhz                 British rule, 1878-1960  eng-latn
#
#       len_spatialCoverage spatialCoverageDescription  start   stop
# 3                       1                     Cyprus  -0950  -0851
# 20                      1                     Cyprus   1572   1913
# 23                      1                     Cyprus  -2500  -1801
# 26                      1                     Cyprus  -1050  -0951
# 32                      1                     Cyprus  -1800  -1651
# 58                      1                     Cyprus   1914   2000
# 126                     1                     Cyprus  -2500  -1801
# 143                     1                     Cyprus  -8800  -6001
# 167                     1                     Cyprus  -0750  -0601
# 199                     1                     Cyprus  -9300  -8801
# 316                     1                     Cyprus  -0050   0149
# 328                     1                     Cyprus   1191   1488
# 351                     1                     Cyprus  -0325  -0151
# 377                     1                     Cyprus  -4000  -2401
# 397                     1                     Cyprus  -0600  -0476
# 411                     1                     Cyprus  -1650  -1051
# 422                     1                     Cyprus  -0850  -0751
# 435                     1                     Cyprus   0250   1190
# 460                     1                     Cyprus  -0150  -0051
# 490                     1                     Cyprus  -4600  -4001
# 516                     1                     Cyprus   0150   0249
# 528                     1                     Cyprus  -0475  -0401
# 562                     1                     Cyprus   1489   1571
# 647                     1                     Cyprus  -0400  -0326
# 1616                    1                     Cyprus   None   None
# 1650                    1                     Cyprus  -1049  -0749
# 1886                    1                     Cyprus  -1649  -1049
# 2177                    1                     Cyprus  -1899  -1649
# 2735                    1                     Cyprus   1878   1949
# 2736                    1                     Cyprus   1950   2008
# ...                   ...                        ...    ...    ...
# 3829                    1                     Cyprus  -8799   None
# 3830                    1                     Cyprus  -0849  -0749
# 3831                    1                     Cyprus  -0149  -0049
# 3832                    1                     Cyprus  -1189  -1149
# 3833                    1                     Cyprus  -1399  -1324
# 3834                    1                     Cyprus  -0474  -0399
# 3835                    1                     Cyprus  -1049  -0949
# 3836                    1                     Cyprus  -0399  -0324
# 3837                    1                     Cyprus  -0324  -0149
# 3838                    1                     Cyprus  -1474  -1399
# 3839                    1                     Cyprus  -0599  -0474
# 3840                    1                     Cyprus  -1049   0250
# 3841                    1                     Cyprus   None   None
# 3842                    1                     Cyprus   0150   0250
# 3843                    1                     Cyprus   None  -2299
# 3844                    1                     Cyprus  -1574  -1474
# 3845                    1                     Cyprus  -1724  -1649
# 3846                    1                     Cyprus  -1899  -1799
# 3847                    1                     Cyprus  -2499  -2074
# 3848                    1                     Cyprus  -1149  -1049
# 3849                    1                     Cyprus  -1649  -1574
# 3850                    1                     Cyprus  -2074  -1999
# 3851                    1                     Cyprus  -1324  -1224
# 3872                    1                     Cyprus   1974   2015
# 4267                    1                     Cyprus   1571   1878
# 4429                    0                     Cyprus   1192   1474
# 4821                    1                     Cyprus   1955   1959
# 4823                    1                     Cyprus   1474   1570
# 5059                    1                     Cyprus   1570   1571
# 5091                    1                     Cyprus   1878   1960
#
# [147 rows x 7 columns]

# %%
queries = [
    RQuery("北宋", label="basic-query"),
    RQuery("bronze age", label="limited-query", limit=1),
    RQuery("Ранньоримський", label="additional-properties-query", properties=[
        RProperty('location', 'Ukraine'),
        RProperty('start', 200),
        RProperty('end', 600)
    ])
]

# %%
r = p_recon.reconcile(queries, method='post')
r
# Out:
# {'additional-properties-query': {'result': [{'id': 'http://n2t.net/ark:/99152/p06v8w4dbcf',
#     'match': True,
#     'name': 'Ранньоримський період [Ukraine, Ukraine: -0049 to 0175]',
#     'score': 0,
#     'type': [{'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#       'name': 'Period definition'}]}]},
#  'basic-query': {'result': [{'id': 'http://n2t.net/ark:/99152/p0fp7wvjvn8',
#     'match': True,
#     'name': 'Northern Song [China, China: 0960 to 1127]',
#     'score': 0,
#     'type': [{'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#       'name': 'Period definition'}]}]},
#  'limited-query': {'result': [{'id': 'http://n2t.net/ark:/99152/p0z3skmnss7',
#     'match': False,
#     'name': 'Bronze [Palestine, Israel, Jordan: -3299 to -1199]',
#     'score': 0,
#     'type': [{'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#       'name': 'Period definition'}]}]}}

# %%
r = p_recon.reconcile([
    RQuery("Roman, Late", properties=[
        RProperty('location', 'Cyprus'),
    ])
], method='post')

r
# Out:
# {'1f30be64-02ca-4a9b-b52f-b350a37e7b02': {'result': []}}
