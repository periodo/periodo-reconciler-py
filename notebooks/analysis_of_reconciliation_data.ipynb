# %%
from itertools import islice
from collections import Counter

import json

from pandas import DataFrame
import pandas as pd
import numpy as np

# %%
from periodo_reconciler import (
    RProperty,
    RQuery,
    PeriodoReconciler
)

p_recon = PeriodoReconciler(host='localhost:8142')

# %%
DATA_PATH = "../data/p0d.json"
rdata = json.load(open(DATA_PATH))

# %%
rdata.keys()
# Out:
# dict_keys(['primaryTopicOf', 'type', 'id', 'periodCollections', '@context'])

# %%
list(rdata['periodCollections'].values())[1]
# Out:
# {'definitions': {'p0znh3t4t68': {'editorialNote': "It is unclear whether the author means the lifespan or reign of Pyrrhus in his description. I have therefore inferred a Start and Stop date from Pyrrhus' lifespan (the broader range). cf. https://en.wikipedia.org/wiki/Pyrrhus_of_Epirus#cite_note-1",
#    'id': 'p0znh3t4t68',
#    'label': 'Florid Style',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Florid Style']},
#    'note': 'p. 288-290: "It is by no means necessary to suppose that one style of fabric ceased immediately on the introduction of another and improved one; on the contrary, it probably continued till so entirely superseded that the fabric became obsolete. Hence the transition from the \'fine\' style of the earlier vases to a subsequent one, which may be termed florid--analogous to the state of art in the time of Pyrrhus."',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Italy',
#      'label': 'Italy'},
#     {'id': 'http://dbpedia.org/resource/Greece', 'label': 'Greece'}],
#    'start': {'in': {'year': '-0318'}, 'label': 'Time of Pyrrhus'},
#    'stop': {'in': {'year': '-0271'}, 'label': 'Time of Pyrrhus'},
#    'type': 'PeriodDefinition'},
#   'p0znh3t5s5w': {'editorialNote': 'Author apparently miscalculates Start date as "Ol. XCIV, B.C. 403". The 94th Olympiad would range from 400 to 396 BC (ISO values: -399 to -395). I have opted to use his more precise dating of "B.C. 403" as a precise Start.\n\nIt is unclear whether author indicates the lifespan or the reign of Pyrrhus when indicating "the time of Pyrrhus" as the period in which the florid style gradually replaced the fine style. I have therefore opted for the wider range (Pyrrhus\' life) to infer an earliest and latest stop. cf. https://en.wikipedia.org/wiki/Pyrrhus_of_Epirus#cite_note-1',
#    'id': 'p0znh3t5s5w',
#    'label': 'Fine Style',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Fine Style']},
#    'note': 'p.285: "The age of these vases is fixed by the appearance of the long vowels, the changed form of the aspirate, and the presence of the double or aspirated letters, introduced into the public acts after the archonship of Euclid, Olympiad XCIV., B.C. 403."\n\np.288-90: "It is by no means necessary to suppose that one style of fabric ceased immediately on the introduction of another and improved one; on the contrary, it probably continued till so entirely superseded that the fabric became obsolete. Hence the transition from the \'fine\' style of the earlier vases to a subsequent one, which may be termed florid -- analogous to the state of art in the time of Pyrrhus."',
#    'source': {'locator': '285, 290',
#     'partOf': 'http://www.worldcat.org/oclc/1358252'},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Italy',
#      'label': 'Italy'},
#     {'id': 'http://dbpedia.org/resource/Greece', 'label': 'Greece'}],
#    'start': {'in': {'year': '-0402'}, 'label': 'B.C. 403'},
#    'stop': {'in': {'earliestYear': '-0318', 'latestYear': '-0271'},
#     'label': 'Time of Pyrrhus'},
#    'type': 'PeriodDefinition'},
#   'p0znh3tjnv8': {'id': 'p0znh3tjnv8',
#    'label': 'Strong Style',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Strong Style']},
#    'note': 'p. 282: "The age of these vases is placed between the L. and LXXX. Olympiads. Recent discoveries have shown that vases of this style are as old as the Parthenon, destroyed by the Persians, Ol. LXXV., B.C. 480, and certainly prior to the age of Pheidias. [see note 3] The vases with the historical subjects of Alcaeus, Ol. XLII., B.C. 612; Anacreon, Ol. LV., B.C. 560; and Croesus, Ol. LVIII., B.C. 548, are in this style. The alphabet resembles that which appears in the Athenian inscriptions of Ol. LXXXVI., B.C. 436, but the language is both Attic and Doric."\n\np.282 n.3: "Jahn, Vasensammlung, s. clxxiv. clxxv; Allg. Monatsschr, 1852, p. 356."',
#    'source': {'locator': '282',
#     'partOf': 'http://www.worldcat.org/oclc/1358252'},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Italy',
#      'label': 'Italy'},
#     {'id': 'http://dbpedia.org/resource/Greece', 'label': 'Greece'}],
#    'start': {'in': {'earliestYear': '-0575', 'latestYear': '-0571'},
#     'label': 'L. Olympiad'},
#    'stop': {'in': {'earliestYear': '-0455', 'latestYear': '-0451'},
#     'label': 'LXXX. Olympiad'},
#    'type': 'PeriodDefinition'},
#   'p0znh3tjqgh': {'id': 'p0znh3tjqgh',
#    'label': 'Decadence',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Decadence']},
#    'note': 'p. 296: "The vases of this style at its best period are later than the introduction of the double letters in the Archonship of Euclid, Olympiad XCIV, B.C. 404, and come down to nearly B.C. 200. [see note 4]"\n\np.296, n. 4: "Thiersch., s. 81-2"',
#    'source': {'locator': '296',
#     'partOf': 'http://www.worldcat.org/oclc/1358252'},
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Italy',
#      'label': 'Italy'},
#     {'id': 'http://dbpedia.org/resource/Greece', 'label': 'Greece'}],
#    'start': {'in': {'year': '-0403'}, 'label': 'B.C. 404'},
#    'stop': {'in': {'year': '-0199'}, 'label': 'B.C. 200'},
#    'type': 'PeriodDefinition'}},
#  'id': 'p0znh3t',
#  'source': {'contributors': [],
#   'creators': [{'id': 'http://experiment.worldcat.org/entity/work/data/1862340418#Person/birch_samuel_1813_1885',
#     'name': 'Samuel Birch'}],
#   'id': 'http://www.worldcat.org/oclc/1358252',
#   'title': 'History of ancient pottery.',
#   'yearPublished': '1858'},
#  'type': 'PeriodCollection'}

# %%
# number of definitions
__builtin__.sum([len(v['definitions']) for v in rdata['periodCollections'].values() ])
# Out:
# 5471

# %%
for (k,v) in rdata['periodCollections'].items():
    print (k, len(v['definitions']))
# Out:
# p08p8mm 0
# p0znh3t 4
# p0f65r2 27
# p0mn2nd 29
# p0qk76z 35
# p0323gx 5
# p06v8w4 212
# p0vhct4 13
# p06ptzs 1
# p047fhm 27
# p0vpm8v 13
# p0fh3zc 2
# p0r2jnt 1
# p08h8hs 3
# p064v7m 13
# p0kh9ds 42
# p0339m9 53
# p0kgptq 4
# p05krdx 31
# p0ff3dt 17
# p0vrf7b 1
# p0z3skm 26
# p0trc5r 5
# p0244q7 1
# p03tcss 6
# p089gcf 11
# p0qhb66 660
# p077pzf 15
# p0dhmkc 2
# p0z5nvh 35
# p0ctc35 9
# p0pf7xr 10
# p0rrjd9 32
# p0mwsd7 1
# p0cfv7g 12
# p0njrb4 10
# p0ccnvb 12
# p0cmdf9 4
# p0bd664 21
# p0367jz 6
# p0ms2ch 5
# p0jrrjb 26
# p0pp7vz 3
# p0qp9rs 55
# p05hrsf 57
# p08nrfc 5
# p0kj6dj 10
# p0m63nj 108
# p03377f 2
# p086kj9 522
# p08tf6p 19
# p08x7cz 2
# p0qwcp6 6
# p0rqpwq 4
# p0bsjms 1
# p0pk6sc 1
# p06xc6m 2
# p0cp447 11
# p077fc5 4
# p06c6g3 1463
# p09xsbn 4
# p0qwjcd 11
# p0d39r7 1
# p0r8d9c 95
# p0dg76f 42
# p0c3bh8 5
# p0jf288 20
# p0pqptc 53
# p05n4hj 11
# p044n25 6
# p0m9pcg 13
# p0wnvm4 1
# p0gjgrs 31
# p044mt9 3
# p0wswdm 3
# p07h9k6 30
# p0s7jn8 2
# p0tns5v 7
# p0hvcwr 1
# p0dfzs7 1
# p0d59sh 5
# p02q72z 2
# p0pf2qb 40
# p0pv57g 18
# p0k7ktv 1
# p083p5r 63
# p0pt6d8 3
# p0jtbzw 31
# p0zmdxz 9
# p0wf3wd 13
# p0vm8tz 4
# p0vn2fr 32
# p0zj6g8 48
# p0sgtfr 1
# p0v28d2 1
# p03wskd 116
# p0hrtx5 1
# p0dfxxp 5
# p02sht9 3
# p03tqbz 2
# p05xnzq 3
# p0swbsk 2
# p0j5frx 4
# p0kc8t6 8
# p0dntkb 3
# p0fp7wv 52
# p08m57h 944

# %%
rdata['periodCollections']['p0bsjms']
# Out:
# {'definitions': {'p0bsjms2dzb': {'id': 'p0bsjms2dzb',
#    'label': 'Republican',
#    'language': 'eng-latn',
#    'localizedLabels': {'eng-latn': ['Republican']},
#    'note': 'Beginning-date corresponds with the end of the Celtiberian wars; outside of the Celtiberian homeland, the Republican period in Spain begins 218 B.C. (Second Punic War).',
#    'spatialCoverage': [{'id': 'http://dbpedia.org/resource/Spain',
#      'label': 'Spain'}],
#    'spatialCoverageDescription': 'Spain',
#    'start': {'in': {'year': '-0132'}, 'label': '133 B.C.'},
#    'stop': {'in': {'year': '-0026'}, 'label': '27 B.C.'},
#    'type': 'PeriodDefinition'}},
#  'id': 'p0bsjms',
#  'source': {'locator': 'pages 3, 52',
#   'partOf': {'creators': [{'id': 'http://viaf.org/viaf/17271321',
#      'name': 'Curchin, Leonard A., 1950-'}],
#    'id': 'http://www.worldcat.org/oclc/51937089',
#    'title': 'The romanization of central Spain : complexity, diversity, and change in a provincial hinterland',
#    'yearPublished': 2004}},
#  'type': 'PeriodCollection'}

# %%
def definitions_from_file(data_path):
    rdata = json.load(open(data_path))
    for v in rdata['periodCollections'].values():
        for definition in v['definitions'].values():
            yield {
                'id':definition['id'],
                'language': definition['language'], 
                'label':definition['label'],
                'start': definition['start'].get('in', {}).get('year'),
                'stop':definition['stop'].get('in', {}).get('year'),
                'spatialCoverageDescription':definition.get('spatialCoverageDescription'),
                'len_spatialCoverage': len(definition.get('spatialCoverage', [])) # definition.get('spatialCoverage', {}).get('label')
            }

# %%
len(list(islice(definitions_from_file(DATA_PATH), None)))
# Out:
# 5471

# %%
list(islice(definitions_from_file(DATA_PATH), 10))
# Out:
# [{'id': 'p0znh3t5s5w',
#   'label': 'Fine Style',
#   'language': 'eng-latn',
#   'len_spatialCoverage': 2,
#   'spatialCoverageDescription': None,
#   'start': '-0402',
#   'stop': None},
#  {'id': 'p0znh3t4t68',
#   'label': 'Florid Style',
#   'language': 'eng-latn',
#   'len_spatialCoverage': 2,
#   'spatialCoverageDescription': None,
#   'start': '-0318',
#   'stop': '-0271'},
#  {'id': 'p0znh3tjqgh',
#   'label': 'Decadence',
#   'language': 'eng-latn',
#   'len_spatialCoverage': 2,
#   'spatialCoverageDescription': None,
#   'start': '-0403',
#   'stop': '-0199'},
#  {'id': 'p0znh3tjnv8',
#   'label': 'Strong Style',
#   'language': 'eng-latn',
#   'len_spatialCoverage': 2,
#   'spatialCoverageDescription': None,
#   'start': None,
#   'stop': None},
#  {'id': 'p0f65r2qmh2',
#   'label': 'Early Bronze',
#   'language': 'eng-latn',
#   'len_spatialCoverage': 7,
#   'spatialCoverageDescription': 'Levant',
#   'start': '-3499',
#   'stop': '-2249'},
#  {'id': 'p0f65r2v4mw',
#   'label': 'Late Bronze',
#   'language': 'eng-latn',
#   'len_spatialCoverage': 7,
#   'spatialCoverageDescription': 'Levant',
#   'start': '-1549',
#   'stop': '-1199'},
#  {'id': 'p0f65r29qvb',
#   'label': 'Iron IIC',
#   'language': 'eng-latn',
#   'len_spatialCoverage': 7,
#   'spatialCoverageDescription': 'Levant',
#   'start': '-0699',
#   'stop': '-0585'},
#  {'id': 'p0f65r2wkwc',
#   'label': 'EB II',
#   'language': 'eng-latn',
#   'len_spatialCoverage': 7,
#   'spatialCoverageDescription': 'Levant',
#   'start': '-3099',
#   'stop': '-2649'},
#  {'id': 'p0f65r2bx9c',
#   'label': 'EB III',
#   'language': 'eng-latn',
#   'len_spatialCoverage': 7,
#   'spatialCoverageDescription': 'Levant',
#   'start': '-2649',
#   'stop': '-2249'},
#  {'id': 'p0f65r2d6pm',
#   'label': 'Iron IIA',
#   'language': 'eng-latn',
#   'len_spatialCoverage': 7,
#   'spatialCoverageDescription': 'Levant',
#   'start': '-0999',
#   'stop': '-0899'}]

# %%
ddf = DataFrame(list(islice(definitions_from_file(DATA_PATH), None)))
ddf.head()
# Out:
#             id         label  language  len_spatialCoverage  \
# 0  p0znh3t5s5w    Fine Style  eng-latn                    2
# 1  p0znh3t4t68  Florid Style  eng-latn                    2
# 2  p0znh3tjqgh     Decadence  eng-latn                    2
# 3  p0znh3tjnv8  Strong Style  eng-latn                    2
# 4  p0f65r2qmh2  Early Bronze  eng-latn                    7
#
#   spatialCoverageDescription  start   stop
# 0                       None  -0402   None
# 1                       None  -0318  -0271
# 2                       None  -0403  -0199
# 3                       None   None   None
# 4                     Levant  -3499  -2249

# %%
ddf.spatialCoverageDescription.value_counts()
# Out:
# Cyprus                                                                                                 147
# Iowa                                                                                                   140
# France                                                                                                 135
# Denmark                                                                                                130
# China                                                                                                  125
# Netherlands                                                                                            125
# Florida                                                                                                123
# Sweden                                                                                                 106
# Crete                                                                                                   87
# United Kingdom                                                                                          83
# Egypt                                                                                                   72
# Greece                                                                                                  71
# Spain                                                                                                   70
# Rome                                                                                                    70
# Romania                                                                                                 66
# Great Britain                                                                                           65
# Kentucky                                                                                                61
# Virginia                                                                                                59
# Bulgaria                                                                                                58
# Aegean                                                                                                  55
# Albania                                                                                                 54
# Slovenia                                                                                                48
# Roman Empire                                                                                            46
# Hungary                                                                                                 45
# Austria                                                                                                 45
# Poland                                                                                                  44
# Byzantine Empire                                                                                        42
# Germany                                                                                                 42
# Sicily                                                                                                  42
# Holy Roman Empire                                                                                       41
#                                                                                                       ...
# Damascus, Syria; All of North Africa west of Egypt; Spain                                                1
# Mongolia; China; 'Abbasid empire; south Russian steppes; central Europe                                  1
# Khurasan; Baghdad; Iraq                                                                                  1
# Jazira and Syria                                                                                         1
# Eastern Anatolia                                                                                         1
# Réunion                                                                                                  1
# 874                     1                     Cyprus  -0400  -0326
# 953                     1                     Cyprus   0250   1190
# 961                     1                     Cyprus  -2500  -1801
# 967                     1                     Cyprus  -0750  -0601
# 1009                    1                     Cyprus  -0600  -0476
# 1044                    1                     Cyprus  -0950  -0851
# 1064                    1                     Cyprus   1572   1913
# 1077                    1                     Cyprus  -0050   0149
# 1090                    1                     Cyprus  -1050  -0951
# 1157                    1                     Cyprus  -0850  -0751
# 1162                    1                     Cyprus   0150   0249
# 1185                    1                     Cyprus  -0150  -0051
# ...                   ...                        ...    ...    ...
# 4194                    1                     Cyprus  -1999  -1899
# 4195                    1                     Cyprus  -0949  -0849
# 4196                    1                     Cyprus  -8799   None
# 4197                    1                     Cyprus  -2499  -2074
# 4198                    1                     Cyprus   None  -2299
# 4199                    1                     Cyprus  -1189  -1149
# 4200                    1                     Cyprus  -1574  -1474
# 4201                    1                     Cyprus  -0399  -0324
# 4202                    1                     Cyprus  -1049  -0949
# 4203                    1                     Cyprus  -1724  -1649
# 4204                    1                     Cyprus  -0149  -0049
# 4205                    1                     Cyprus  -1899  -1799
# 4206                    1                     Cyprus   0150   0250
# 4207                    1                     Cyprus  -1149  -1049
# 4208                    1                     Cyprus  -0049   0150
# 4209                    1                     Cyprus   None  -2499
# 4210                    1                     Cyprus  -0324  -0149
# 4211                    1                     Cyprus  -1399  -1324
# 4212                    1                     Cyprus  -0749  -0599
# 4213                    1                     Cyprus  -1049   0250
# 4214                    1                     Cyprus  -1324  -1224
# 4215                    1                     Cyprus  -1474  -1399
# 4216                    1                     Cyprus  -0849  -0749
# 4217                    1                     Cyprus  -1224  -1189
# 4218                    1                     Cyprus   None   None
# 4219                    1                     Cyprus  -1649  -1574
# 4785                    1                     Cyprus  -1899  -1649
# 5087                    1                     Cyprus  -1649  -1049
# 5167                    1                     Cyprus  -1049  -0749
# 5176                    1                     Cyprus   None   None
#
# [147 rows x 7 columns]

# %%
queries = [
    RQuery("北宋", label="basic-query"),
    RQuery("bronze age", label="limited-query", limit=1),
    RQuery("Ранньоримський", label="additional-properties-query", properties=[
        RProperty('location', 'Ukraine'),
        RProperty('start', 200),
        RProperty('end', 600)
    ])
]

# %%
r = p_recon.reconcile(queries, method='post')
r
# Out:
# {'additional-properties-query': {'result': [{'id': 'http://n2t.net/ark:/99152/p06v8w4dbcf',
#     'match': True,
#     'name': 'Ранньоримський період [Ukraine, Ukraine: -0049 to 0175]',
#     'score': 0,
#     'type': [{'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#       'name': 'Period definition'}]}]},
#  'basic-query': {'result': [{'id': 'http://n2t.net/ark:/99152/p0fp7wvjvn8',
#     'match': True,
#     'name': 'Northern Song [China, China: 0960 to 1127]',
#     'score': 0,
#     'type': [{'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#       'name': 'Period definition'}]}]},
#  'limited-query': {'result': [{'id': 'http://n2t.net/ark:/99152/p0z3skmnss7',
#     'match': False,
#     'name': 'Bronze [Palestine, Israel, Jordan: -3299 to -1199]',
#     'score': 0,
#     'type': [{'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#       'name': 'Period definition'}]}]}}

# %%
r = p_recon.reconcile([
    RQuery("Roman, Late", properties=[
        RProperty('location', 'Cyprus'),
    ])
], method='post')

r
# Out:
# {'2a36e898-c175-4234-a17e-1182137bf910': {'result': []}}

# %%
len(ddf)
# Out:
# 5471

# %%
```
RProperty('location', 'Spain'),
        RProperty('start', -1500),
        RProperty('end', -714)
```

# %%
# number, None, or something else

def classify_start(x):
    if x is None:
        return 'None'
    elif x is np.nan:
        return 'Nan'
    try:
        x1 = np.float(x)
        return 'Number'
    except:
        return 'Other'

# %%
classify_start(1), classify_start(None), classify_start(np.nan), classify_start('hello')
# Out:
# ('Number', 'None', 'Nan', 'Other')

# %%
ddf.start.apply(classify_start).value_counts()
# Out:
# Number    5331
# None       140
# Name: start, dtype: int64

# %%
def possible_spatial_temporal(location, start, stop, 
                              location_strict=False,
                              start_strict=False,
                              stop_strict=False):

    def f(row):
        
        location_ok = False
        if location_strict:
            if ((row['spatialCoverageDescription'] is not None) and
                (location is not None) and (row['spatialCoverageDescription'] == location)):
                location_ok = True
        else:  # location_strict False
            if ((row['spatialCoverageDescription'] is None) or
                (location is None) or 
                (row['spatialCoverageDescription'] == location)):
                location_ok = True

        start_ok = False
        if start_strict:
            if ((row['stop'] is not None) and
                (start is not None) and
                (np.float(start) <= np.float(row['stop']))):
                start_ok = True
        else: 
            if ((row['stop'] is None) or
                (start is None) or 
                (np.float(start) <= np.float(row['stop']))):
                start_ok = True

        stop_ok = False
        if stop_strict:
            if ((row['start'] is not None) and
                (stop is not None) and
                (np.float(stop) >= np.float(row['start']))):
                stop_ok = True
        else:
            if ((row['start'] is None) or
                (stop is None) or 
                (np.float(stop) >= np.float(row['start']))):
                stop_ok = True
            
        return location_ok and start_ok and stop_ok
    
    return f

# %%
ddf.head()
# Out:
#             id         label  language  len_spatialCoverage  \
# 0  p0znh3t5s5w    Fine Style  eng-latn                    2
# 1  p0znh3t4t68  Florid Style  eng-latn                    2
# 2  p0znh3tjqgh     Decadence  eng-latn                    2
# 3  p0znh3tjnv8  Strong Style  eng-latn                    2
# 4  p0f65r2qmh2  Early Bronze  eng-latn                    7
#
#   spatialCoverageDescription  start   stop
# 0                       None  -0402   None
# 1                       None  -0318  -0271
# 2                       None  -0403  -0199
# 3                       None   None   None
# 4                     Levant  -3499  -2249

# %%
location = "Spain"
start = -1500
stop = -714


ddf[ddf.apply(possible_spatial_temporal(location,start,stop, location_strict=True), axis=1)]
# Out:
#                id                    label  language  len_spatialCoverage  \
# 155   p06v8w4q5mm          Edad del Bronce  spa-latn                    1
# 284   p06v8w4s9pz          Edad del Hierro  spa-latn                    1
# 734   p0qhb6666wx          Edad del Hierro  spa-latn                    1
# 827   p0qhb669k7t    Edad del Bronce Final  spa-latn                    1
# 939   p0qhb66z4gr    Edad del Bronce Media  spa-latn                    1
# 1118  p0qhb668ps5          Edad del Bronce  spa-latn                    1
# 1237  p0qhb664vm3  Primera Edad del Hierro  spa-latn                    1
#
#      spatialCoverageDescription  start   stop
# 155                       Spain  -2299  -1000
# 284                       Spain  -0999   0000
# 734                       Spain  -0800  -0051
# 827                       Spain  -1200  -0801
# 939                       Spain  -1700  -1201
# 1118                      Spain  -2300  -0801
# 1237                      Spain  -0800  -0401
