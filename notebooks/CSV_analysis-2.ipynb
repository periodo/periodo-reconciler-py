# %%
import csv
import io
import contextlib
import os, errno
from collections import OrderedDict, Counter

from IPython.core.display import display, HTML

from pandas import DataFrame
import pandas as pd
import numpy as np

from periodo_reconciler import (
    RProperty,
    RQuery,
    PeriodoReconciler,
    CsvReconciler
)

# %%
def output_path_name(inpath, test_data_dir="../test-data/",
                     test_output_dir="../test-output/"):
    """
    given a path in the test directory, return the path for corresponding output in the test output dir
    """
 
    return os.path.join(test_output_dir, os.path.relpath(inpath, start=test_data_dir))

def makedirs_for_path(fpath):
    """
    make sure that the directory for fpath exists
    """
    
    (fdir, fname) = os.path.split(fpath)
    try:
        os.makedirs(fdir)
    except OSError as e:
        if e.errno != errno.EEXIST:
            raise
            
    return True

# %%
def reconcile_to_csv_df(csv_path, kw, p_recon):
    """
    Inputs:  
    csv_path: the path of the csv file to reconcile
    kw: a dict holding the query, location, start, stop fields
    p_recon: a PeriodoReconciler object
    
    Side-effect:
    * a csv file with the matches in the output directory
    * returns a Pandas DataFrame holding the input data along with match data
    
    """

    output_path = output_path_name(csv_path)
    makedirs_for_path(output_path)
    
    # https://stackoverflow.com/a/19412700/7782
    with contextlib.ExitStack() as stack:
        csvfile = stack.enter_context(open(csv_path))
        outputfile = stack.enter_context(open(output_path, "w"))                  

        # p_recon = PeriodoReconciler(host='localhost:8142')
        c_recon = CsvReconciler(csvfile, p_recon, **kw)

        matches = list(c_recon.matches())

        match_summary = io.StringIO()
        c_recon.match_summary_to_csv(match_summary)
        
        c_recon.to_csv(outputfile, matches)
        
        df = DataFrame(matches)
        df_summary = pd.read_csv(io.StringIO(match_summary.getvalue()))
        

        return (df, df_summary)

# %% [markdown]
# # simple example of running the reconciler against a CSV file

# %%
# simple example

csv_path = "../test-data/periodo_simple_example.csv"
kw = {
   'location': 'location',
   'query': 'query',
   'start': 'start',
   'stop': 'end',
   'transpose_query': True,
   'match_top_candidate': True
}

p_recon = PeriodoReconciler(host='localhost:8142')
(df, match_summary) = reconcile_to_csv_df(csv_path, kw, p_recon)

df.match_num.value_counts(), match_summary
# Out:
# (1    4
#  0    1
#  Name: match_num, dtype: int64,
#              query location  start   stop  match_num  \
#  0              北宋      NaN    NaN    NaN          1
#  1      bronze age      NaN    NaN    NaN          0
#  2  Ранньоримський  Ukraine  200.0  600.0          1
#  3      Late Roman   Cyprus  300.0  749.0          1
#  4     Roman, Late   Cyprus  300.0  749.0          1
#
#                                            match_name  \
#  0         Northern Song [China, China: 0960 to 1127]
#  1  Bronze [Palestine, Israel, Jordan: -3299 to -1...
#  2  Ранньоримський період [Ukraine, Ukraine: -0049...
#  3          Late Roman [Cyprus, Cyprus: 0300 to 0749]
#  4          Late Roman [Cyprus, Cyprus: 0300 to 0749]
#
#                                  match_id  candidates_count  match_fallback_id  \
#  0  http://n2t.net/ark:/99152/p0fp7wvjvn8                 1                NaN
#  1  http://n2t.net/ark:/99152/p0z3skmnss7                83                NaN
#  2  http://n2t.net/ark:/99152/p06v8w4dbcf                 1                NaN
#  3  http://n2t.net/ark:/99152/p0dg76fbqff                 1                NaN
#  4  http://n2t.net/ark:/99152/p0dg76fbqff                 1                NaN
#
#     match_fallback_name  row_count
#  0                  NaN          1
#  1                  NaN          1
#  2                  NaN          1
#  3                  NaN          1
#  4                  NaN          1  )

# %% [markdown]
# # OpenContext examples

# %%
# the list of OpenContext CSV files along with the columns to be fed to the reconciler

OPENCONTEXT_TEST_FILES = [{'csv_path': '../test-data/OpenContext/Cyprus PKAP Survey.csv',
  'kw': {'location': 'Context (1)',
   'query': 'Period',
   'start': 'Early BCE/CE',
   'stop': 'Late BCE/CE',
   'transpose_query': True,
   'match_top_candidate': True}},
 {'csv_path': '../test-data/OpenContext/Cyprus-PKAP-Survey-2019-03-29.csv',
  'kw': {'location': 'Context (1)',
   'query': 'periodo-pre-match',
   'start': 'Early BCE/CE',
   'stop': 'Late BCE/CE'}},
 {'csv_path': '../test-data/OpenContext/European Cattle with Periods.csv',
  'kw': {'location': 'Context (1)',
   'query': 'Period',
   'start': 'Early BCE/CE',
   'stop': 'Late BCE/CE',
   'ignored_queries':'Not determined'
  }},
 {'csv_path': '../test-data/OpenContext/Petra Artifacts.csv',
  'kw': {'location': 'Context (1)',
   'query': 'Culture',
   'start': 'Early BCE/CE',
   'stop': 'Late BCE/CE',
   'ignored_queries':'other,lb'
    }}]


kw_map = dict([(f['csv_path'], f['kw']) for f in OPENCONTEXT_TEST_FILES])

# %%
matching_results = {}
match_summaries = {}

p_recon = PeriodoReconciler(host='localhost:8142')

for file in OPENCONTEXT_TEST_FILES:
    csv_path = file['csv_path']
    kw = file['kw']
    print ("\r{}".format(csv_path), end='')
    (df, match_summary)  = reconcile_to_csv_df(csv_path, kw, p_recon)
    matching_results[csv_path] = df # df.match_num.value_counts()
    match_summaries[csv_path] = match_summary
# Out:
# ../test-data/OpenContext/Petra Artifacts.csvh Periods.csvv

# %%
from itertools import islice

for (csv_path, df) in islice(matching_results.items(),None):
    print (csv_path, df.match_num.value_counts().get(0), df.match_num.value_counts().get(1))
# Out:
# ../test-data/OpenContext/Cyprus PKAP Survey.csv 5381 3056
# ../test-data/OpenContext/Cyprus-PKAP-Survey-2019-03-29.csv 5381 3056
# ../test-data/OpenContext/European Cattle with Periods.csv 5270 398
# ../test-data/OpenContext/Petra Artifacts.csv 52181 306

# %% [markdown]
# # PKAP

# %%
df = matching_results[OPENCONTEXT_TEST_FILES[0]['csv_path']]

df.head()
# Out:
#                                                  URI       Item Label  \
# 0  http://opencontext.org/subjects/8C2A609B-B20B-...  Batch 131 (exp)
# 1  http://opencontext.org/subjects/636D6826-BCBD-...         Batch 17
# 2  http://opencontext.org/subjects/CA8C3EE0-0F09-...         Batch 19
# 3  http://opencontext.org/subjects/622BEE81-FC52-...  Batch 140 (exp)
# 4  http://opencontext.org/subjects/58920419-0245-...    Batch 7 (exp)
#
#                                        Project Label  \
# 0  Pyla-Koutsopetria Archaeological Project I: Pe...
# 1  Pyla-Koutsopetria Archaeological Project I: Pe...
# 2  Pyla-Koutsopetria Archaeological Project I: Pe...
# 3  Pyla-Koutsopetria Archaeological Project I: Pe...
# 4  Pyla-Koutsopetria Archaeological Project I: Pe...
#
#                                          Project URI Context (1)  \
# 0  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 1  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 2  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 3  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 4  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
#
#         Context (2) Context (3) Context (4) Context (5)  \
# 0  PKAP Survey Area       Vigla    Unit 501
# 1  PKAP Survey Area   Dhekeleia    Unit 223
# 2  PKAP Survey Area   West Pyla    Unit 546
# 3  PKAP Survey Area       Vigla    Unit 501
# 4  PKAP Survey Area       Vigla    Unit 501
#
#                                          Context URI         ...          \
# 0  http://opencontext.org/subjects/C3EDBDC2-6B6B-...         ...
# 1  http://opencontext.org/subjects/8E773523-4391-...         ...
# 2  http://opencontext.org/subjects/34C7E1EC-F44D-...         ...
# 3  http://opencontext.org/subjects/C3EDBDC2-6B6B-...         ...
# 4  http://opencontext.org/subjects/C3EDBDC2-6B6B-...         ...
#
#   Material               Period Extant Part Fabric group candidates_count  \
# 0  pottery          Roman, Late         rim       coarse                1
# 1  pottery          Roman, Late      handle      amphora                1
# 2  pottery          Roman, Late      handle      amphora                1
# 3  pottery            Classical      handle         fine                8
# 4  pottery  Archaic-Hellenistic      handle       coarse               19
#
#   match_num                                         match_name  \
# 0         1          Late Roman [Cyprus, Cyprus: 0300 to 0749]
# 1         1          Late Roman [Cyprus, Cyprus: 0300 to 0749]
# 2         1          Late Roman [Cyprus, Cyprus: 0300 to 0749]
# 3         0  Classical (Greco-Roman; 550 BC-330 BC) [Afghan...
# 4         0  Archaic-Hellenistic [Cyprus, Cyprus: -0749 to ...
#
#                                 match_id match_fallback_id match_fallback_name
# 0  http://n2t.net/ark:/99152/p0dg76fbqff
# 1  http://n2t.net/ark:/99152/p0dg76fbqff
# 2  http://n2t.net/ark:/99152/p0dg76fbqff
# 3  http://n2t.net/ark:/99152/p03wskd389m
# 4  http://n2t.net/ark:/99152/p0dg76f4rhx
#
# [5 rows x 30 columns]

# %%
len(df)
# Out:
# 8437

# %%
df.candidates_count.value_counts()
# Out:
# 1     3056
# 2     2813
# 5      789
# 0      443
# 24     384
# 10     202
# 12     178
# 11     137
# 8      121
# 6       97
# 7       69
# 9       50
# 18      40
# 19      40
# 3        8
# 16       5
# 15       4
# 4        1
# Name: candidates_count, dtype: int64

# %%
# rewrite CSV to patch up rows with out any matches

# %%
from collections import Counter, defaultdict

c = defaultdict(Counter)

c['bach'].update(['1','2'])
c['mozart'].update([3])

# %%
c['bach'].most_common(1)[0]
# Out:
# ('1', 1)

# %%
c
# Out:
# defaultdict(collections.Counter,
#             {'bach': Counter({'1': 1, '2': 1}), 'mozart': Counter({3: 1})})

# %%
df.match_fallback_id.value_counts()
# Out:
#                                          8365
# http://n2t.net/ark:/99152/p0dg76f2smn      70
# http://n2t.net/ark:/99152/p0dg76fbqff       1
# http://n2t.net/ark:/99152/p0dg76fkv78       1
# Name: match_fallback_id, dtype: int64

# %%
df[(df.match_id == '') & (df.match_fallback_id == '')]
# Out:
#                                                     URI            Item Label  \
# 129   http://opencontext.org/subjects/1771E5F4-E411-...               Batch 1
# 553   http://opencontext.org/subjects/7F33E5E7-128F-...        Artifact 51.46
# 878   http://opencontext.org/subjects/4C15D78A-03FD-...        Artifact 70.52
# 2215  http://opencontext.org/subjects/35AF81FE-78EE-...       Artifact 204.27
# 3173  http://opencontext.org/subjects/8C921D14-B3E3-...        Artifact 61.33
# 3622  http://opencontext.org/subjects/110F1828-175C-...        Artifact 101.9
# 7348  http://opencontext.org/subjects/E4DFB59D-D5B0-...        Artifact 62.36
# 7471  http://opencontext.org/subjects/68F96348-BB88-...         Artifact 9.42
# 7608  http://opencontext.org/subjects/6E68F6A7-4002-...    Artifact [18.1].42
# 7621  http://opencontext.org/subjects/8523872D-763A-...        Artifact 71.45
# 7676  http://opencontext.org/subjects/81B9E644-29C8-...         Artifact 8.43
# 7685  http://opencontext.org/subjects/63F45383-C517-...        Artifact 71.42
# 7693  http://opencontext.org/subjects/E2A7D7D0-409D-...        Artifact 70.35
# 7696  http://opencontext.org/subjects/8C28E5CD-4398-...       Artifact 208.21
# 7701  http://opencontext.org/subjects/6F72C17A-E140-...        Artifact 51.47
# 7710  http://opencontext.org/subjects/5A9BF7B6-6A84-...         Artifact 9.38
# 7745  http://opencontext.org/subjects/D61F8FC6-6856-...        Artifact 25.33
# 7811  http://opencontext.org/subjects/0ECA5FAA-26D8-...       Artifact 203.31
# 7821  http://opencontext.org/subjects/90447217-23BC-...        Artifact 60.23
# 7822  http://opencontext.org/subjects/0D6B79B4-6101-...        Artifact 13.17
# 7828  http://opencontext.org/subjects/C2484CBD-5224-...        Artifact 47.39
# 7829  http://opencontext.org/subjects/5A0852BC-06CB-...        Artifact 68.21
# 7839  http://opencontext.org/subjects/A1DDDAD8-87D6-...        Artifact 70.46
# 7851  http://opencontext.org/subjects/15911CC6-0BC8-...        Artifact 222.7
# 7853  http://opencontext.org/subjects/F80841BC-F0E2-...        Artifact 71.39
# 7925  http://opencontext.org/subjects/DF86C0F3-6A13-...        Artifact 73.33
# 7926  http://opencontext.org/subjects/693DE74C-73F4-...  Artifact [127.1].44A
# 7929  http://opencontext.org/subjects/55E9052D-4495-...       Artifact 223.24
# 7931  http://opencontext.org/subjects/642D6F39-93F1-...        Artifact 11.45
# 7932  http://opencontext.org/subjects/231B4B66-22A8-...        Artifact 76.38
# ...                                                 ...                   ...
# 8407  http://opencontext.org/subjects/80838D08-FD6F-...      Artifact 60.24.1
# 8408  http://opencontext.org/subjects/F23F67DB-4335-...      Artifact 51.44.1
# 8409  http://opencontext.org/subjects/23BA0607-7521-...      Artifact 10.11.1
# 8410  http://opencontext.org/subjects/EA31AD53-2DE8-...      Artifact 64.45.1
# 8411  http://opencontext.org/subjects/E3464F14-3F6D-...       Artifact 501.44
# 8412  http://opencontext.org/subjects/D857CB37-F6C7-...  Artifact [18.1].46.1
# 8413  http://opencontext.org/subjects/956B3E07-3857-...        Artifact 73.35
# 8414  http://opencontext.org/subjects/9DAA4D98-E3C8-...     Artifact 546.50.1
# 8415  http://opencontext.org/subjects/C8E6A429-7A37-...     Artifact 71.1.122
# 8416  http://opencontext.org/subjects/3CDA5A2C-A632-...      Artifact 62.41.1
# 8417  http://opencontext.org/subjects/4124F7D5-96A5-...        Artifact 57.28
# 8418  http://opencontext.org/subjects/56EAE9C7-C903-...     Artifact 71.1.120
# 8419  http://opencontext.org/subjects/7ABAEA37-AD47-...        Artifact 7.20a
# 8420  http://opencontext.org/subjects/366CED75-26D4-...        Artifact 222.8
# 8421  http://opencontext.org/subjects/E00425B5-6B7D-...       Artifact 188.40
# 8422  http://opencontext.org/subjects/BF351984-D1E3-...      Artifact 47.38.1
# 8423  http://opencontext.org/subjects/0E6E9749-6385-...        Artifact 5.35A
# 8424  http://opencontext.org/subjects/BF5D8704-33B0-...  Artifact [120.1].25A
# 8425  http://opencontext.org/subjects/AF4D2684-277B-...    Artifact [40.1].50
# 8426  http://opencontext.org/subjects/27E3BBCD-C13F-...        Artifact 51.31
# 8427  http://opencontext.org/subjects/9398C94D-8369-...       Artifact 233.23
# 8428  http://opencontext.org/subjects/09584285-46E9-...     Artifact 546.51.1
# 8429  http://opencontext.org/subjects/706DEB68-1AFF-...       Artifact 541.22
# 8430  http://opencontext.org/subjects/DF624735-F17A-...        Artifact 213.7
# 8431  http://opencontext.org/subjects/7055A8A5-673C-...    Artifact [71.1].64
# 8432  http://opencontext.org/subjects/0510F97A-6575-...         Artifact 70.5
# 8433  http://opencontext.org/subjects/1398002F-673D-...       Artifact 542.24
# 8434  http://opencontext.org/subjects/F2CFBDA3-5FEB-...         Artifact 74.4
# 8435  http://opencontext.org/subjects/B25C7FC3-85FE-...       Artifact 241.13
# 8436  http://opencontext.org/subjects/E6AB6FD4-A3B1-...      Artifact 71.1.74
#
#                                           Project Label  \
# 129   Pyla-Koutsopetria Archaeological Project I: Pe...
# 553   Pyla-Koutsopetria Archaeological Project I: Pe...
# 878   Pyla-Koutsopetria Archaeological Project I: Pe...
# 2215  Pyla-Koutsopetria Archaeological Project I: Pe...
# 3173  Pyla-Koutsopetria Archaeological Project I: Pe...
# 3622  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7348  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7471  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7608  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7621  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7676  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7685  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7693  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7696  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7701  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7710  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7745  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7811  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7821  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7822  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7828  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7829  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7839  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7851  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7853  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7925  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7926  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7929  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7931  Pyla-Koutsopetria Archaeological Project I: Pe...
# 7932  Pyla-Koutsopetria Archaeological Project I: Pe...
# ...                                                 ...
# 8407  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8408  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8409  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8410  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8411  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8412  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8413  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8414  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8415  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8416  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8417  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8418  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8419  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8420  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8421  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8422  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8423  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8424  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8425  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8426  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8427  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8428  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8429  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8430  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8431  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8432  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8433  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8434  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8435  Pyla-Koutsopetria Archaeological Project I: Pe...
# 8436  Pyla-Koutsopetria Archaeological Project I: Pe...
#
#                                             Project URI Context (1)  \
# 129   http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 553   http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 878   http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 2215  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 3173  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 3622  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7348  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7471  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7608  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7621  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7676  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7685  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7693  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7696  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7701  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7710  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7745  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7811  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7821  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7822  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7828  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7829  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7839  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7851  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7853  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7925  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7926  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7929  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7931  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 7932  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# ...                                                 ...         ...
# 8407  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8408  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8409  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8410  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8411  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8412  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8413  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8414  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8415  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8416  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8417  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8418  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8419  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8420  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8421  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8422  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8423  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8424  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8425  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8426  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8427  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8428  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8429  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8430  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8431  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8432  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8433  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8434  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8435  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
# 8436  http://opencontext.org/projects/3F6DCD13-A476-...      Cyprus
#
#            Context (2)                 Context (3) Context (4) Context (5)  \
# 129   PKAP Survey Area                 Vigla-Ridge   Unit 1402
# 553   PKAP Survey Area                 Paleokastro     Unit 51    Batch 46
# 878   PKAP Survey Area                 Paleokastro     Unit 70    Batch 52
# 2215  PKAP Survey Area         Kokkinokremos Plain    Unit 204    Batch 27
# 3173  PKAP Survey Area                 Paleokastro     Unit 61    Batch 33
# 3622  PKAP Survey Area                 Paleokastro    Unit 101     Batch 9
# 7348  PKAP Survey Area                 Paleokastro     Unit 62    Batch 36
# 7471  PKAP Survey Area  Koutsopetria - Paleokastro      Unit 9    Batch 42
# 7608  PKAP Survey Area  Koutsopetria - Paleokastro     Unit 18    Batch 42
# 7621  PKAP Survey Area                 Paleokastro     Unit 71    Batch 45
# 7676  PKAP Survey Area  Koutsopetria - Paleokastro      Unit 8    Batch 43
# 7685  PKAP Survey Area                 Paleokastro     Unit 71    Batch 42
# 7693  PKAP Survey Area                 Paleokastro     Unit 70    Batch 35
# 7696  PKAP Survey Area         Kokkinokremos Plain    Unit 208    Batch 21
# 7701  PKAP Survey Area                 Paleokastro     Unit 51    Batch 47
# 7710  PKAP Survey Area  Koutsopetria - Paleokastro      Unit 9    Batch 38
# 7745  PKAP Survey Area  Koutsopetria - Paleokastro     Unit 25    Batch 33
# 7811  PKAP Survey Area         Kokkinokremos Plain    Unit 203    Batch 31
# 7821  PKAP Survey Area                 Paleokastro     Unit 60    Batch 23
# 7822  PKAP Survey Area  Koutsopetria - Paleokastro     Unit 13    Batch 17
# 7828  PKAP Survey Area                 Paleokastro     Unit 47    Batch 39
# 7829  PKAP Survey Area                 Paleokastro     Unit 68    Batch 21
# 7839  PKAP Survey Area                 Paleokastro     Unit 70    Batch 46
# 7851  PKAP Survey Area                   Dhekeleia    Unit 222     Batch 7
# 7853  PKAP Survey Area                 Paleokastro     Unit 71    Batch 39
# 7925  PKAP Survey Area                 Paleokastro     Unit 73    Batch 33
# 7926  PKAP Survey Area                 Water Plant    Unit 127    Batch 44
# 7929  PKAP Survey Area                   Dhekeleia    Unit 223    Batch 24
# 7931  PKAP Survey Area  Koutsopetria - Paleokastro     Unit 11    Batch 45
# 7932  PKAP Survey Area                 Paleokastro     Unit 76    Batch 38
# ...                ...                         ...         ...         ...
# 8407  PKAP Survey Area                 Paleokastro     Unit 60    Batch 24
# 8408  PKAP Survey Area                 Paleokastro     Unit 51    Batch 44
# 8409  PKAP Survey Area  Koutsopetria - Paleokastro     Unit 10    Batch 11
# 8410  PKAP Survey Area                 Paleokastro     Unit 64    Batch 45
# 8411  PKAP Survey Area                       Vigla    Unit 501    Batch 44
# 8412  PKAP Survey Area  Koutsopetria - Paleokastro     Unit 18    Batch 46
# 8413  PKAP Survey Area                 Paleokastro     Unit 73    Batch 35
# 8414  PKAP Survey Area                   West Pyla    Unit 546    Batch 50
# 8415  PKAP Survey Area                 Paleokastro     Unit 71   Batch 122
# 8416  PKAP Survey Area                 Paleokastro     Unit 62    Batch 41
# 8417  PKAP Survey Area                 Paleokastro     Unit 57    Batch 28
# 8418  PKAP Survey Area                 Paleokastro     Unit 71   Batch 120
# 8419  PKAP Survey Area  Koutsopetria - Paleokastro      Unit 7    Batch 20
# 8420  PKAP Survey Area                   Dhekeleia    Unit 222     Batch 8
# 8421  PKAP Survey Area         Kokkinokremos Plain    Unit 188    Batch 40
# 8422  PKAP Survey Area                 Paleokastro     Unit 47    Batch 38
# 8423  PKAP Survey Area  Koutsopetria - Paleokastro      Unit 5    Batch 35
# 8424  PKAP Survey Area                 Water Plant    Unit 120    Batch 25
# 8425  PKAP Survey Area                 Paleokastro     Unit 40    Batch 50
# 8426  PKAP Survey Area                 Paleokastro     Unit 51    Batch 31
# 8427  PKAP Survey Area         Kokkinokremos Plain    Unit 233    Batch 23
# 8428  PKAP Survey Area                   West Pyla    Unit 546    Batch 51
# 8429  PKAP Survey Area                   West Pyla    Unit 541    Batch 22
# 8430  PKAP Survey Area                   Dhekeleia    Unit 213     Batch 7
# 8431  PKAP Survey Area                 Paleokastro     Unit 71    Batch 64
# 8432  PKAP Survey Area                 Paleokastro     Unit 70     Batch 5
# 8433  PKAP Survey Area                   West Pyla    Unit 542    Batch 24
# 8434  PKAP Survey Area                 Paleokastro     Unit 74     Batch 4
# 8435  PKAP Survey Area         Kokkinokremos Plain    Unit 241    Batch 13
# 8436  PKAP Survey Area                 Paleokastro     Unit 71    Batch 74
#
#                                             Context URI         ...          \
# 129   http://opencontext.org/subjects/A3CE5232-A6A1-...         ...
# 553   http://opencontext.org/subjects/EC9D2A24-5D58-...         ...
# 878   http://opencontext.org/subjects/F6A912DD-4379-...         ...
# 2215  http://opencontext.org/subjects/71386C7D-3B5C-...         ...
# 3173  http://opencontext.org/subjects/66E4F080-0820-...         ...
# 3622  http://opencontext.org/subjects/1ABAE5B5-0CD8-...         ...
# 7348  http://opencontext.org/subjects/C7032FAD-4CCF-...         ...
# 7471  http://opencontext.org/subjects/06D17669-1EFC-...         ...
# 7608  http://opencontext.org/subjects/F2A86EA6-42CD-...         ...
# 7621  http://opencontext.org/subjects/2D99013E-B7E0-...         ...
# 7676  http://opencontext.org/subjects/1B86108D-305D-...         ...
# 7685  http://opencontext.org/subjects/18E24569-5373-...         ...
# 7693  http://opencontext.org/subjects/A7F5A965-076E-...         ...
# 7696  http://opencontext.org/subjects/7F71B3B7-AFF8-...         ...
# 7701  http://opencontext.org/subjects/391DA1ED-67B9-...         ...
# 7710  http://opencontext.org/subjects/443EC56F-2016-...         ...
# 7745  http://opencontext.org/subjects/62187478-206A-...         ...
# 7811  http://opencontext.org/subjects/657CC40B-89E4-...         ...
# 7821  http://opencontext.org/subjects/084704F8-4455-...         ...
# 7822  http://opencontext.org/subjects/65FDFC7C-5465-...         ...
# 7828  http://opencontext.org/subjects/3E085445-5D20-...         ...
# 7829  http://opencontext.org/subjects/32BA2B94-3B6B-...         ...
# 7839  http://opencontext.org/subjects/68CBAE99-2EAD-...         ...
# 7851  http://opencontext.org/subjects/11E69A8B-2177-...         ...
# 7853  http://opencontext.org/subjects/6AC9C392-A6FA-...         ...
# 7925  http://opencontext.org/subjects/5AE21C02-8535-...         ...
# 7926  http://opencontext.org/subjects/B7408D70-94C1-...         ...
# 7929  http://opencontext.org/subjects/39EED66C-EF2E-...         ...
# 7931  http://opencontext.org/subjects/8767AC9C-64B5-...         ...
# 7932  http://opencontext.org/subjects/AB503505-CB3A-...         ...
# ...                                                 ...         ...
# 8407  http://opencontext.org/subjects/2FCAA1AF-4A7A-...         ...
# 8408  http://opencontext.org/subjects/A9EED450-9DD5-...         ...
# 8409  http://opencontext.org/subjects/7BB0E232-6110-...         ...
# 8410  http://opencontext.org/subjects/25497C8D-8361-...         ...
# 8411  http://opencontext.org/subjects/51129890-E4D4-...         ...
# 8412  http://opencontext.org/subjects/B8FD989D-27ED-...         ...
# 8413  http://opencontext.org/subjects/5AD2CF07-7BE2-...         ...
# 8414  http://opencontext.org/subjects/1616B8FD-E67F-...         ...
# 8415  http://opencontext.org/subjects/732B9D6C-1644-...         ...
# 8416  http://opencontext.org/subjects/0A98D65B-F485-...         ...
# 8417  http://opencontext.org/subjects/5BDC1151-FBBD-...         ...
# 8418  http://opencontext.org/subjects/401C8DE8-96EB-...         ...
# 8419  http://opencontext.org/subjects/46A50E3C-CEAC-...         ...
# 8420  http://opencontext.org/subjects/CA783B5F-4A7F-...         ...
# 8421  http://opencontext.org/subjects/351C76F4-80CC-...         ...
# 8422  http://opencontext.org/subjects/05F6AD59-0C10-...         ...
# 8423  http://opencontext.org/subjects/860BE2A7-AACC-...         ...
# 8424  http://opencontext.org/subjects/BE146437-C446-...         ...
# 8425  http://opencontext.org/subjects/A2A56A1E-8B0D-...         ...
# 8426  http://opencontext.org/subjects/515E1F3D-4CE2-...         ...
# 8427  http://opencontext.org/subjects/FE1E59AD-6E87-...         ...
# 8428  http://opencontext.org/subjects/2CB191C6-A43F-...         ...
# 8429  http://opencontext.org/subjects/34201D0A-43CE-...         ...
# 8430  http://opencontext.org/subjects/970AB31A-16CF-...         ...
# 8431  http://opencontext.org/subjects/3397F91B-CA29-...         ...
# 8432  http://opencontext.org/subjects/D3E1556B-E5AE-...         ...
# 8433  http://opencontext.org/subjects/339F518B-DDF3-...         ...
# 8434  http://opencontext.org/subjects/2C4E7BFF-EA83-...         ...
# 8435  http://opencontext.org/subjects/1A0450F3-57EB-...         ...
# 8436  http://opencontext.org/subjects/A7B90F10-44E2-...         ...
#
#            Material Period Extant Part Fabric group candidates_count  \
# 129   stone/lithics                rim                             0
# 553                                                                0
# 878                                                                0
# 2215                                                               0
# 3173                                                               0
# 3622                                                               0
# 7348                                                               0
# 7471                                                               0
# 7608                                                               0
# 7621                                                               0
# 7676                                                               0
# 7685                                                               0
# 7693                                                               0
# 7696                                                               0
# 7701                                                               0
# 7710                                                               0
# 7745                                                               0
# 7811                                                               0
# 7821                                                               0
# 7822                                                               0
# 7828                                                               0
# 7829                                                               0
# 7839                                                               0
# 7851                                                               0
# 7853                                                               0
# 7925                                                               0
# 7926                                                               0
# 7929                                                               0
# 7931                                                               0
# 7932                                                               0
# ...             ...    ...         ...          ...              ...
# 8407                                                               0
# 8408                                                               0
# 8409                                                               0
# 8410                                                               0
# 8411                                                               0
# 8412                                                               0
# 8413                                                               0
# 8414                                                               0
# 8415                                                               0
# 8416                                                               0
# 8417                                                               0
# 8418                                                               0
# 8419                                                               0
# 8420                                                               0
# 8421                                                               0
# 8422                                                               0
# 8423                                                               0
# 8424                                                               0
# 8425                                                               0
# 8426                                                               0
# 8427                                                               0
# 8428                                                               0
# 8429                                                               0
# 8430                                                               0
# 8431                                                               0
# 8432                                                               0
# 8433                                                               0
# 8434                                                               0
# 8435                                                               0
# 8436                                                               0
#
#      match_num match_name match_id match_fallback_id match_fallback_name
# 129          0
# 553          0
# 878          0
# 2215         0
# 3173         0
# 3622         0
# 7348         0
# 7471         0
# 7608         0
# 7621         0
# 7676         0
# 7685         0
# 7693         0
# 7696         0
# 7701         0
# 7710         0
# 7745         0
# 7811         0
# 7821         0
# 7822         0
# 7828         0
# 7829         0
# 7839         0
# 7851         0
# 7853         0
# 7925         0
# 7926         0
# 7929         0
# 7931         0
# 7932         0
# ...        ...        ...      ...               ...                 ...
# 8407         0
# 8408         0
# 8409         0
# 8410         0
# 8411         0
# 8412         0
# 8413         0
# 8414         0
# 8415         0
# 8416         0
# 8417         0
# 8418         0
# 8419         0
# 8420         0
# 8421         0
# 8422         0
# 8423         0
# 8424         0
# 8425         0
# 8426         0
# 8427         0
# 8428         0
# 8429         0
# 8430         0
# 8431         0
# 8432         0
# 8433         0
# 8434         0
# 8435         0
# 8436         0
#
# [371 rows x 30 columns]

# %%
df_summary = match_summaries['../test-data/OpenContext/Cyprus PKAP Survey.csv']
df_summary
# Out:
#                                query location  start   stop  match_num  \
# 0                   Ancient Historic   Cyprus   -750    749          0
# 1                        Roman, Late   Cyprus    300    749          1
# 2                              Roman   Cyprus    -99    749          0
# 3        Late Bronze Age-Hellenistic   Cyprus  -1650   -100          0
# 4                                NaN   Cyprus    300    749          0
# 5                           Iron Age   Cyprus  -1050   -312          0
# 6                            Unknown   Cyprus  -9000  -9000          1
# 7                        Hellenistic   Cyprus   -311   -100          0
# 8            Hellenistic-Early Roman   Cyprus   -311    299          0
# 9                       Roman, Early   Cyprus    -99    299          0
# 10                            Modern   Cyprus   1878   1878          0
# 11                   Medieval-Modern   Cyprus   1191   1191          0
# 12                  Ancient-Medieval   Cyprus  -3500   1570          1
# 13                           Unknown   Cyprus  -2500  -2500          1
# 14                           Unknown   Cyprus  FALSE  FALSE          0
# 15                  Post-Prehistoric   Cyprus   -999   -999          1
# 16  Late Cypriot II-Late Cypriot III   Cyprus  -1450  -1050          0
# 17                   Classical-Roman   Cyprus   -474    749          0
# 18               Archaic-Hellenistic   Cyprus   -750   -100          0
# 19                               NaN   Cyprus   -750    749          0
# 20             Classical-Hellenistic   Cyprus   -474   -100          0
# 21                           Ancient   Cyprus  -9000    749          1
# 22                   Modern, Present   Cyprus   1949   1950          0
# 23                           Archaic   Cyprus   -750   -475          0
# 24                               NaN   Cyprus    -99    749          0
# 25                               NaN   Cyprus  FALSE  FALSE          0
# 26                   Late Cypriot II   Cyprus  -1450  -1200          0
# 27                               NaN   Cyprus    -99    299          0
# 28                               NaN   Cyprus   -750   -100          0
# 29                         Classical   Cyprus   -474   -312          0
# ..                               ...      ...    ...    ...        ...
# 49                               NaN   Cyprus  -1050   -312          0
# 50                               NaN   Cyprus   -311   -100          0
# 51                 Geometric-Archaic   Cyprus  -1050   -475          0
# 52                 Hellenistic-Roman   Cyprus   -311    749          0
# 53              Late Cypriot-Archaic   Cyprus  -1650   -475          0
# 54                               NaN   Cyprus   -474   -312          0
# 55                               NaN   Cyprus   -750   -475          0
# 56                       Ceramic Age   Cyprus  -1700  -1700          1
# 57        Medieval, Ottoman/Venetian   Cyprus   1191   1877          0
# 58                          Medieval   Cyprus   1191   1570          0
# 59                     Cypro-Archaic   Cyprus   -750   -475          1
# 60                   Medieval, Early   Cyprus   1191   1570          1
# 61        Medieval, Ottoman/Venetian   Cyprus   1571   1877          0
# 62                       Roman, Late   Cyprus  FALSE  FALSE          0
# 63         Ancient Historic-Medieval   Cyprus   -750   1570          0
# 64                        Late Roman   Cyprus    300    749          1
# 65                   Medieval, Early   Cyprus    750   1190          1
# 66                       Ceramic Age   Cyprus  -3500  -3500          1
# 67                Iron Age-Classical   Cyprus  -1050   -312          0
# 68        Protogeometric-Hellenistic   Cyprus  -1050   -100          0
# 69             Classical-Hellenistic   Cyprus  FALSE  FALSE          0
# 70                           Unknown   Cyprus   -311   -311          1
# 71                               NaN   Cyprus   1878   1878          0
# 72                               NaN   Cyprus   -474    749          0
# 73                               NaN   Cyprus   -311    299          0
# 74                               NaN   Cyprus   -999   -999          0
# 75                               NaN   Cyprus  -9000  -9000          0
# 76                               NaN   Cyprus   1571   1877          0
# 77                               NaN   Cyprus    750   1570          0
# 78                               NaN   Cyprus  -2500  -1000          0
#
#                                            match_name  \
# 0    Ancient Historic [Cyprus, Cyprus: -0749 to 0749]
# 1           Late Roman [Cyprus, Cyprus: 0300 to 0749]
# 2               Roman [Cyprus, Cyprus: -0098 to 0749]
# 3   Late Bronze Age (= Late Cypriot) [Cyprus, Cypr...
# 4                                                 NaN
# 5           Iron Age [Cyprus, Cyprus: -1049 to -0311]
# 6             Unknown [Cyprus, Cyprus: -8999 to 2008]
# 7        Hellenistic [Cyprus, Cyprus: -0310 to -0099]
# 8   Hellenistic-Early Roman [Cyprus, Cyprus: -0310...
# 9         Early Roman [Cyprus, Cyprus: -0098 to 0299]
# 10  Modern (AD 1700-Present) [Afghanistan, Albania...
# 11            Medieval [Cyprus, Cyprus: 0750 to 1570]
# 12   Ancient-Medieval [Cyprus, Cyprus: -3499 to 1570]
# 13            Unknown [Cyprus, Cyprus: -8999 to 2008]
# 14                                                NaN
# 15   Post-Prehistoric [Cyprus, Cyprus: -0998 to 2008]
# 16  Late Cypriot II-Late Cypriot III [Cyprus, Cypr...
# 17    Classical-Roman [Cyprus, Cyprus: -0473 to 0749]
# 18  Archaic-Hellenistic [Cyprus, Cyprus: -0749 to ...
# 19                                                NaN
# 20  Classical-Hellenistic [Cyprus, Cyprus: -0473 t...
# 21            Ancient [Cyprus, Cyprus: -8999 to 0749]
# 22              Modern [Cyprus, Cyprus: 1870 to 2008]
# 23           Archaic [Cyprus, Cyprus: -0749 to -0474]
# 24                                                NaN
# 25                                                NaN
# 26   Late Cypriot II [Cyprus, Cyprus: -1449 to -1199]
# 27                                                NaN
# 28                                                NaN
# 29  Classical (Greco-Roman; 550 BC-330 BC) [Afghan...
# ..                                                ...
# 49                                                NaN
# 50                                                NaN
# 51  Geometric (Cypro-Geometric) III [Cyprus, Cypru...
# 52  Hellenistic-Roman [Cyprus, Cyprus: -0310 to 0749]
# 53  Late Cypriot-Archaic [Cyprus, Cyprus: -1649 to...
# 54                                                NaN
# 55                                                NaN
# 56        Ceramic Age [Cyprus, Cyprus: -3499 to 2008]
# 57  Late Medieval-Ottoman [Cyprus, Cyprus: 1191 to...
# 58            Medieval [Cyprus, Cyprus: 0750 to 1570]
# 59             Cypro-Archaic [Cyprus: -0749 to -0449]
# 60      Early Medieval [Cyprus, Cyprus: 0750 to 1190]
# 61             Ottoman [Cyprus, Cyprus: 1571 to 1877]
# 62                                                NaN
# 63  Ancient Historic-Medieval [Cyprus, Cyprus: -07...
# 64          Late Roman [Cyprus, Cyprus: 0300 to 0749]
# 65      Early Medieval [Cyprus, Cyprus: 0750 to 1190]
# 66        Ceramic Age [Cyprus, Cyprus: -3499 to 2008]
# 67          Iron Age [Cyprus, Cyprus: -1049 to -0311]
# 68  Protogeometric-Hellenistic [Cyprus, Cyprus: -1...
# 69                                                NaN
# 70            Unknown [Cyprus, Cyprus: -8999 to 2008]
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
#
#                                  match_id  candidates_count  \
# 0   http://n2t.net/ark:/99152/p0dg76fxkgg                 2
# 1   http://n2t.net/ark:/99152/p0dg76fbqff                 1
# 2   http://n2t.net/ark:/99152/p0dg76fx784                 5
# 3   http://n2t.net/ark:/99152/p083p5rpb46                24
# 4                                     NaN                 0
# 5   http://n2t.net/ark:/99152/p0dg76f6zd3                10
# 6   http://n2t.net/ark:/99152/p0dg76f2smn                 1
# 7   http://n2t.net/ark:/99152/p0dg76fqj57                11
# 8   http://n2t.net/ark:/99152/p0dg76fk9wq                12
# 9   http://n2t.net/ark:/99152/p0dg76fpqkt                 2
# 10  http://n2t.net/ark:/99152/p03wskdgh6j                 8
# 11  http://n2t.net/ark:/99152/p0dg76f5ndh                 6
# 12  http://n2t.net/ark:/99152/p0dg76fjh5t                 1
# 13  http://n2t.net/ark:/99152/p0dg76f2smn                 1
# 14                                    NaN                 0
# 15  http://n2t.net/ark:/99152/p0dg76f98q7                 1
# 16  http://n2t.net/ark:/99152/p0dg76f664z                 7
# 17  http://n2t.net/ark:/99152/p0dg76frgs8                12
# 18  http://n2t.net/ark:/99152/p0dg76f4rhx                19
# 19                                    NaN                 0
# 20  http://n2t.net/ark:/99152/p0dg76fkv78                18
# 21  http://n2t.net/ark:/99152/p0dg76fj92d                 1
# 22  http://n2t.net/ark:/99152/p0dg76fqd7r                 9
# 23  http://n2t.net/ark:/99152/p0dg76fwn27                 9
# 24                                    NaN                 0
# 25                                    NaN                 0
# 26  http://n2t.net/ark:/99152/p0dg76fgb4s                 5
# 27                                    NaN                 0
# 28                                    NaN                 0
# 29  http://n2t.net/ark:/99152/p03wskd389m                 8
# ..                                    ...               ...
# 49                                    NaN                 0
# 50                                    NaN                 0
# 51  http://n2t.net/ark:/99152/p0jtbzw932g                16
# 52  http://n2t.net/ark:/99152/p0dg76f4hkq                15
# 53  http://n2t.net/ark:/99152/p0dg76fvqdg                15
# 54                                    NaN                 0
# 55                                    NaN                 0
# 56  http://n2t.net/ark:/99152/p0dg76fzg6j                 1
# 57  http://n2t.net/ark:/99152/p0dg76f2kc2                11
# 58  http://n2t.net/ark:/99152/p0dg76f5ndh                 3
# 59  http://n2t.net/ark:/99152/p08m57h2cv3                 1
# 60  http://n2t.net/ark:/99152/p0dg76fq5c5                 1
# 61  http://n2t.net/ark:/99152/p0dg76fv3nv                10
# 62                                    NaN                 0
# 63  http://n2t.net/ark:/99152/p0dg76f83qp                 4
# 64  http://n2t.net/ark:/99152/p0dg76fbqff                 1
# 65  http://n2t.net/ark:/99152/p0dg76fq5c5                 1
# 66  http://n2t.net/ark:/99152/p0dg76fzg6j                 1
# 67  http://n2t.net/ark:/99152/p0dg76f6zd3                18
# 68  http://n2t.net/ark:/99152/p0dg76f5cnh                11
# 69                                    NaN                 0
# 70  http://n2t.net/ark:/99152/p0dg76f2smn                 1
# 71                                    NaN                 0
# 72                                    NaN                 0
# 73                                    NaN                 0
# 74                                    NaN                 0
# 75                                    NaN                 0
# 76                                    NaN                 0
# 77                                    NaN                 0
# 78                                    NaN                 0
#
#                         match_fallback_id  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14  http://n2t.net/ark:/99152/p0dg76f2smn
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28                                    NaN
# 29                                    NaN
# ..                                    ...
# 49                                    NaN
# 50                                    NaN
# 51                                    NaN
# 52                                    NaN
# 53                                    NaN
# 54                                    NaN
# 55                                    NaN
# 56                                    NaN
# 57                                    NaN
# 58                                    NaN
# 59                                    NaN
# 60                                    NaN
# 61                                    NaN
# 62  http://n2t.net/ark:/99152/p0dg76fbqff
# 63                                    NaN
# 64                                    NaN
# 65                                    NaN
# 66                                    NaN
# 67                                    NaN
# 68                                    NaN
# 69  http://n2t.net/ark:/99152/p0dg76fkv78
# 70                                    NaN
# 71                                    NaN
# 72                                    NaN
# 73                                    NaN
# 74                                    NaN
# 75                                    NaN
# 76                                    NaN
# 77                                    NaN
# 78                                    NaN
#
#                                   match_fallback_name  row_count
# 0                                                 NaN       2665
# 1                                                 NaN       2594
# 2                                                 NaN        766
# 3                                                 NaN        384
# 4                                                 NaN        216
# 5                                                 NaN        201
# 6                                                 NaN        179
# 7                                                 NaN        130
# 8                                                 NaN        130
# 9                                                 NaN        125
# 10                                                NaN        101
# 11                                                NaN         93
# 12                                                NaN         92
# 13                                                NaN         76
# 14            Unknown [Cyprus, Cyprus: -8999 to 2008]         70
# 15                                                NaN         60
# 16                                                NaN         55
# 17                                                NaN         48
# 18                                                NaN         40
# 19                                                NaN         40
# 20                                                NaN         39
# 21                                                NaN         28
# 22                                                NaN         25
# 23                                                NaN         25
# 24                                                NaN         25
# 25                                                NaN         18
# 26                                                NaN         16
# 27                                                NaN         15
# 28                                                NaN         15
# 29                                                NaN         14
# ..                                                ...        ...
# 49                                                NaN          3
# 50                                                NaN          3
# 51                                                NaN          2
# 52                                                NaN          2
# 53                                                NaN          2
# 54                                                NaN          2
# 55                                                NaN          2
# 56                                                NaN          1
# 57                                                NaN          1
# 58                                                NaN          1
# 59                                                NaN          1
# 60                                                NaN          1
# 61                                                NaN          1
# 62          Late Roman [Cyprus, Cyprus: 0300 to 0749]          1
# 63                                                NaN          1
# 64                                                NaN          1
# 65                                                NaN          1
# 66                                                NaN          1
# 67                                                NaN          1
# 68                                                NaN          1
# 69  Classical-Hellenistic [Cyprus, Cyprus: -0473 t...          1
# 70                                                NaN          1
# 71                                                NaN          1
# 72                                                NaN          1
# 73                                                NaN          1
# 74                                                NaN          1
# 75                                                NaN          1
# 76                                                NaN          1
# 77                                                NaN          1
# 78                                                NaN          1
#
# [79 rows x 11 columns]

# %%
df_summary.row_count.sum()
# Out:
# 8437
